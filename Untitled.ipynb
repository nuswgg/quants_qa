# %%
import QUANTAXIS as QA

# %%
###获取全部股票列表
# stock_list=QA.QA_fetch_stock_list_adv().code.to_list()
cn_stk_list = QA.QA_fetch_stock_list()

# %%
###获取财务数据
df=QA.QA_fetch_financial_report_adv(stock_list,'2017-01-01','2020-01-01',ltype ='CN')

# %%
cn_stk_list

# %%
bk=QA.QA_fetch_stock_block_adv()
# idx=QA.QA_fetch_stock_block()
# type(idx)
type(bk.view_block)
# Out:
# blockname
# 300周期     [000001, 000002, 000069, 000166, 000627, 00062...
# 300非周     [000063, 000100, 000157, 000333, 000338, 00041...
# 3D打印      [000638, 000928, 000938, 000969, 000988, 00200...
# 4G5G      [300747, 002902, 300548, 000636, 603678, 30040...
# 5G概念      [000063, 000070, 000547, 000586, 000636, 00066...
# C2M概念     [000521, 002042, 002094, 002193, 002269, 00234...
# ETC概念     [000948, 000997, 002017, 002049, 002104, 00233...
# IP变现      [000673, 000793, 000802, 000892, 002174, 00217...
# MSCI中国    [000001, 000002, 000027, 000039, 000050, 00006...
# MSCI中盘    [000021, 000027, 000028, 000031, 000046, 00006...
# MSCI成份    [000001, 000002, 000039, 000050, 000063, 00006...
# MSCI概念    [600436, 603799, 002714, 002466, 600535, 60086...
# O2O概念     [300662, 603558, 300003, 600729, 002154, 00229...
# OLED      [300657, 300037, 300327, 002326, 000973, 00287...
# OLED概念    [000012, 000045, 000050, 000100, 000413, 00053...
# ...

# %%
bk.view_block['300周期']
# Out:
# ['000001',
#  '000002',
#  '000069',
#  '000166',
#  '000627',
#  '000629',
#  '000630',
#  '000656',
#  '000671',
#  '000709',
#  '000728',
#  '000776',
#  '000783',
#  '000786',
#  '000898',
#  '000961',
#  '001979',
#  '002032',
#  '002142',
#  '002146',
#  '002271',
#  '002460',
#  '002466',
#  '002673',
#  '002736',
#  '002939',
#  '002945',
#  '002958',
#  '300059',
#  '600000',
#  '600004',
#  '600009',
#  '600010',
#  '600015',
#  '600016',
#  '600018',
#  '600019',
#  '600028',
#  '600029',
#  '600030',
#  '600036',
#  '600048',
#  '600061',
#  '600109',
#  '600111',
#  '600115',
#  '600176',
#  '600188',
#  '600208',
#  '600219',
#  '600221',
#  '600340',
#  '600362',
#  '600369',
#  '600383',
#  '600390',
#  '600489',
#  '600516',
#  '600547',
#  '600583',
#  '600585',
#  '600606',
#  '600660',
#  '600663',
#  '600705',
#  '600816',
#  '600837',
#  '600848',
#  '600919',
#  '600926',
#  '600928',
#  '600958',
#  '600968',
#  '600999',
#  '601006',
#  '601009',
# ...

# %%
#获取所有指数代码
ind_list=idx_list.code.to_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a18d3d191595> in <module>()
#       1 #获取所有指数代码
# ----> 2 ind_list=idx_list.code.to_list()
#
# NameError: name 'idx_list' is not defined
