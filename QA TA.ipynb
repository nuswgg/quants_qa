# %%
from QUANTAXIS.QAIndicator.base import HHV, LLV, SMA, CROSS, BARLAST, REF, COUNT

# %%
import QUANTAXIS as QA

# %%
dir(QA.QAIndicator.base)
# Out:
# ['ABS',
#  'AVEDEV',
#  'BARLAST',
#  'BARLAST_EXIST',
#  'BBI',
#  'BBIBOLL',
#  'COUNT',
#  'CROSS',
#  'CROSS_STATUS',
#  'DIFF',
#  'EMA',
#  'FILTER',
#  'HHV',
#  'IF',
#  'IFAND',
#  'IFOR',
#  'LAST',
#  'LLV',
#  'MA',
#  'MACD',
#  'MAX',
#  'MIN',
#  'REF',
#  'RENKO',
#  'RENKOP',
#  'SINGLE_CROSS',
#  'SMA',
#  'STD',
#  'SUM',
#  'XARROUND',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'math',
#  'np',
#  'pd',
#  'reduce']

# %%
dir(QA.BROKER_TYPE)
# Out:
# ['BACKETEST',
#  'RANDOM',
#  'REAL',
#  'SHIPANE',
#  'SIMULATION',
#  'TTS',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
dir(QA.QA_Market)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_close',
#  '_renew_account',
#  '_settle',
#  '_sync_deals',
#  '_sync_orders',
#  '_sync_position',
#  '_trade',
#  'cancel_all',
#  'cancel_order',
#  'clear',
#  'connect',
#  'every_day_start',
#  'get_account',
#  'get_account_cookie',
#  'get_api_last_error',
#  'get_api_version',
#  'get_client_id',
#  'get_trading_day',
#  'insert_order',
#  'login',
#  'logout',
#  'next_tradeday',
#  'on_cancel_order',
#  'on_cancel_order_event',
#  'on_connect',
#  'on_error',
#  'on_insert_order',
#  'on_order_event',
#  'on_query_assets',
#  'on_query_data',
# ...

# %%
dir(QA.QA_Portfolio)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'accounts',
#  'add_account',
#  'buy',
#  'buy_close',
#  'buy_open',
#  'cancel_order',
#  'cash_available',
#  'cash_table',
#  'change_cash',
#  'close_positions_order',
#  'code',
#  'cookie_mangement',
#  'create_futureaccount',
#  'create_stockaccount',
#  'current_hold_price',
#  'current_time',
#  'daily_cash',
#  'daily_frozen',
#  'daily_hold',
#  'date',
#  'drop_account',
#  'end_date',
#  'freecash_precent',
#  'from_message',
#  'from_otgdict',
#  'generate_randomtrade',
#  'get_account',
#  'get_account_by_cookie',
#  'get_cash',
# ...

# %%
dir(QA.QA_User)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_coins',
#  'change_wechatid',
#  'coins_table',
#  'generate_simpleaccount',
#  'get_account',
#  'get_portfolio',
#  'message',
#  'new_portfolio',
#  'register_account',
#  'reload',
#  'save',
#  'sub_code',
#  'subscribe_strategy',
#  'subscribed_code',
#  'subscribed_strategy',
#  'subscribing_strategy',
#  'sync',
#  'table',
#  'unsub_code',
#  'unsubscribe_stratgy']

# %%
dir(QA.QA_Account)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'buy',
#  'buy_close',
#  'buy_open',
#  'cancel_order',
#  'cash_table',
#  'change_cash',
#  'close_positions_order',
#  'code',
#  'current_hold_price',
#  'current_time',
#  'daily_cash',
#  'daily_frozen',
#  'daily_hold',
#  'date',
#  'end_date',
#  'freecash_precent',
#  'from_message',
#  'from_otgdict',
#  'generate_randomtrade',
#  'get_history',
#  'get_orders',
#  'history_min',
#  'history_table',
#  'history_table_min',
#  'hold',
#  'hold_available',
#  'hold_price',
#  'hold_table',
#  'hold_time',
#  'init_assets',
#  'init_hold_with_account',
# ...

# %%
dir(QA.QA_BacktestBroker)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'get_market',
#  'query_data',
#  'query_deal',
#  'query_order',
#  'query_orders',
#  'query_positions',
#  'receive_order',
#  'run',
#  'warp']
