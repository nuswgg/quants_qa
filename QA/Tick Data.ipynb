# %% [markdown]
# https://go.ctolib.com/shidenggui-easyquotation.html

# %%
import easyquotation as equ

# %%
quotation = equ.use('sina') # 新浪 ['sina'] 腾讯 ['tencent', 'qq']

# %%
quotation.stocks('000001')
# Out:
# {'000001': {'name': '平安银行',
#   'open': 15.18,
#   'close': 15.34,
#   'now': 15.01,
#   'high': 15.3,
#   'low': 14.82,
#   'buy': 15.01,
#   'sell': 15.02,
#   'turnover': 95423625,
#   'volume': 1431844020.44,
#   'bid1_volume': 135880,
#   'bid1': 15.01,
#   'bid2_volume': 807560,
#   'bid2': 15.0,
#   'bid3_volume': 124400,
#   'bid3': 14.99,
#   'bid4_volume': 274568,
#   'bid4': 14.98,
#   'bid5_volume': 97300,
#   'bid5': 14.97,
#   'ask1_volume': 153900,
#   'ask1': 15.02,
#   'ask2_volume': 22900,
#   'ask2': 15.03,
#   'ask3_volume': 106500,
#   'ask3': 15.04,
#   'ask4_volume': 165335,
#   'ask4': 15.05,
#   'ask5_volume': 11700,
#   'ask5': 15.06,
#   'date': '2020-09-11',
#   'time': '15:00:03'}}

# %%
quotation.market_snapshot(prefix=True)
# Out:
# {'sz000001': {'name': '平安银行',
#   'open': 15.18,
#   'close': 15.34,
#   'now': 15.01,
#   'high': 15.3,
#   'low': 14.82,
#   'buy': 15.01,
#   'sell': 15.02,
#   'turnover': 95423625,
#   'volume': 1431844020.44,
#   'bid1_volume': 135880,
#   'bid1': 15.01,
#   'bid2_volume': 807560,
#   'bid2': 15.0,
#   'bid3_volume': 124400,
#   'bid3': 14.99,
#   'bid4_volume': 274568,
#   'bid4': 14.98,
#   'bid5_volume': 97300,
#   'bid5': 14.97,
#   'ask1_volume': 153900,
#   'ask1': 15.02,
#   'ask2_volume': 22900,
#   'ask2': 15.03,
#   'ask3_volume': 106500,
#   'ask3': 15.04,
#   'ask4_volume': 165335,
#   'ask4': 15.05,
#   'ask5_volume': 11700,
#   'ask5': 15.06,
#   'date': '2020-09-11',
#   'time': '15:00:03'},
#  'sz000002': {'name': '万科Ａ',
#   'open': 28.46,
#   'close': 28.46,
#   'now': 28.0,
#   'high': 28.46,
#   'low': 27.9,
#   'buy': 27.99,
#   'sell': 28.0,
#   'turnover': 54110837,
#   'volume': 1519932745.31,
#   'bid1_volume': 58699,
#   'bid1': 27.99,
# ...

# %%
# 单只股票
quotation.real('162411') # 支持直接指定前缀，如 'sh000001'
# Out:
# {'162411': {'name': '华宝油气',
#   'open': 0.253,
#   'close': 0.259,
#   'now': 0.256,
#   'high': 0.257,
#   'low': 0.253,
#   'buy': 0.256,
#   'sell': 0.257,
#   'turnover': 159740695,
#   'volume': 40674458.98,
#   'bid1_volume': 5921755,
#   'bid1': 0.256,
#   'bid2_volume': 13337200,
#   'bid2': 0.255,
#   'bid3_volume': 10322700,
#   'bid3': 0.254,
#   'bid4_volume': 10498916,
#   'bid4': 0.253,
#   'bid5_volume': 4878500,
#   'bid5': 0.252,
#   'ask1_volume': 2278204,
#   'ask1': 0.257,
#   'ask2_volume': 2836766,
#   'ask2': 0.258,
#   'ask3_volume': 1380111,
#   'ask3': 0.259,
#   'ask4_volume': 2004756,
#   'ask4': 0.26,
#   'ask5_volume': 1819718,
#   'ask5': 0.261,
#   'date': '2020-09-11',
#   'time': '15:00:03'}}

# %%
quotation.real('sh000001') # 支持直接指定前缀，如 'sh000001'
# Out:
# {'000001': {'name': '上证指数',
#   'open': 3225.7836,
#   'close': 3234.8234,
#   'now': 3260.3461,
#   'high': 3262.4976,
#   'low': 3220.5363,
#   'buy': 0.0,
#   'sell': 0.0,
#   'turnover': 221698830,
#   'volume': 254844994260.0,
#   'bid1_volume': 0,
#   'bid1': 0.0,
#   'bid2_volume': 0,
#   'bid2': 0.0,
#   'bid3_volume': 0,
#   'bid3': 0.0,
#   'bid4_volume': 0,
#   'bid4': 0.0,
#   'bid5_volume': 0,
#   'bid5': 0.0,
#   'ask1_volume': 0,
#   'ask1': 0.0,
#   'ask2_volume': 0,
#   'ask2': 0.0,
#   'ask3_volume': 0,
#   'ask3': 0.0,
#   'ask4_volume': 0,
#   'ask4': 0.0,
#   'ask5_volume': 0,
#   'ask5': 0.0,
#   'date': '2020-09-11',
#   'time': '15:02:13'}}

# %%
quotation.real('000001') # 支持直接指定前缀，如 'sh000001'
# Out:
# {'000001': {'name': '平安银行',
#   'open': 15.18,
#   'close': 15.34,
#   'now': 15.01,
#   'high': 15.3,
#   'low': 14.82,
#   'buy': 15.01,
#   'sell': 15.02,
#   'turnover': 95423625,
#   'volume': 1431844020.44,
#   'bid1_volume': 135880,
#   'bid1': 15.01,
#   'bid2_volume': 807560,
#   'bid2': 15.0,
#   'bid3_volume': 124400,
#   'bid3': 14.99,
#   'bid4_volume': 274568,
#   'bid4': 14.98,
#   'bid5_volume': 97300,
#   'bid5': 14.97,
#   'ask1_volume': 153900,
#   'ask1': 15.02,
#   'ask2_volume': 22900,
#   'ask2': 15.03,
#   'ask3_volume': 106500,
#   'ask3': 15.04,
#   'ask4_volume': 165335,
#   'ask4': 15.05,
#   'ask5_volume': 11700,
#   'ask5': 15.06,
#   'date': '2020-09-11',
#   'time': '15:00:03'}}

# %%
# 多只股票
quotation.stocks(['000001', '000002'])
# Out:
# {'000001': {'name': '平安银行',
#   'open': 15.18,
#   'close': 15.34,
#   'now': 15.01,
#   'high': 15.3,
#   'low': 14.82,
#   'buy': 15.01,
#   'sell': 15.02,
#   'turnover': 95423625,
#   'volume': 1431844020.44,
#   'bid1_volume': 135880,
#   'bid1': 15.01,
#   'bid2_volume': 807560,
#   'bid2': 15.0,
#   'bid3_volume': 124400,
#   'bid3': 14.99,
#   'bid4_volume': 274568,
#   'bid4': 14.98,
#   'bid5_volume': 97300,
#   'bid5': 14.97,
#   'ask1_volume': 153900,
#   'ask1': 15.02,
#   'ask2_volume': 22900,
#   'ask2': 15.03,
#   'ask3_volume': 106500,
#   'ask3': 15.04,
#   'ask4_volume': 165335,
#   'ask4': 15.05,
#   'ask5_volume': 11700,
#   'ask5': 15.06,
#   'date': '2020-09-11',
#   'time': '15:00:03'},
#  '000002': {'name': '万科Ａ',
#   'open': 28.46,
#   'close': 28.46,
#   'now': 28.0,
#   'high': 28.46,
#   'low': 27.9,
#   'buy': 27.99,
#   'sell': 28.0,
#   'turnover': 54110837,
#   'volume': 1519932745.31,
#   'bid1_volume': 58699,
#   'bid1': 27.99,
# ...

# %%
# 同时获取指数和行情
quotation.stocks(['sh000001', 'sz000001'], prefix=True)
# Out:
# {'sh000001': {'name': '上证指数',
#   'open': 3225.7836,
#   'close': 3234.8234,
#   'now': 3260.3461,
#   'high': 3262.4976,
#   'low': 3220.5363,
#   'buy': 0.0,
#   'sell': 0.0,
#   'turnover': 221698830,
#   'volume': 254844994260.0,
#   'bid1_volume': 0,
#   'bid1': 0.0,
#   'bid2_volume': 0,
#   'bid2': 0.0,
#   'bid3_volume': 0,
#   'bid3': 0.0,
#   'bid4_volume': 0,
#   'bid4': 0.0,
#   'bid5_volume': 0,
#   'bid5': 0.0,
#   'ask1_volume': 0,
#   'ask1': 0.0,
#   'ask2_volume': 0,
#   'ask2': 0.0,
#   'ask3_volume': 0,
#   'ask3': 0.0,
#   'ask4_volume': 0,
#   'ask4': 0.0,
#   'ask5_volume': 0,
#   'ask5': 0.0,
#   'date': '2020-09-11',
#   'time': '15:02:13'},
#  'sz000001': {'name': '平安银行',
#   'open': 15.18,
#   'close': 15.34,
#   'now': 15.01,
#   'high': 15.3,
#   'low': 14.82,
#   'buy': 15.01,
#   'sell': 15.02,
#   'turnover': 95423625,
#   'volume': 1431844020.44,
#   'bid1_volume': 135880,
#   'bid1': 15.01,
#   'bid2_volume': 807560,
#   'bid2': 15.0,
# ...

# %%
# 选择 jsl（集思路） 行情
quotation = equ.use('jsl') # ['jsl']

# %%
# 获取分级基金信息
quotation.funda() # 参数可选择利率、折价率、交易量、有无下折、是否永续来过滤
quotation.fundb() # 参数如上
# Out:
# {'150033': {'fundb_base_fund_id': '160718',
#   'funda_id': '150032',
#   'funda_name': '多利优先',
#   'fundb_id': '150033',
#   'fundb_name': '多利进取',
#   'status_cd': 'N',
#   'recalc_to': None,
#   'calc_info': '',
#   'upper_recalc_price': None,
#   'maturity_dt': None,
#   'coupon_descr': '固定5.0%',
#   'coupon_descr_s': '5.0%',
#   'coupon': '5.000',
#   'manage_fee': '0.900',
#   'funda_current_price': '1.011',
#   'funda_upper_price': '1.123',
#   'funda_lower_price': '0.919',
#   'funda_increase_rt': '-0.98',
#   'fundb_current_price': '0.959',
#   'fundb_upper_price': '1.035',
#   'fundb_lower_price': '0.847',
#   'fundb_increase_rt': '1.91%',
#   'fundb_volume': '0.05',
#   'fundb_value': '0.9600',
#   'fundb_nav_dt': '2020-09-11',
#   'fundm_value': '1.0104',
#   'fundm_nav_dt': '2020-09-11',
#   'fundb_discount_rt': '-0.10%',
#   'fundb_price_leverage_rt': '5.268',
#   'fundb_net_leverage_rt': '5.263',
#   'fundb_capital_rasising_rt': '6.00%',
# ...
