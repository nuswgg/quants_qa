# %%
import QUANTAXIS as QA
# Out:
# jqdatasdk not installed

# %%
N = 40
mu = 1

# %%
import pandas as pd
def strategy001(data, N=40, mu=1):
    MP = QA.MA((data.high+data.low+data.close)/3, N)
    TR = pd.concat([abs(data.high - data.low), abs(data.high- data.close.shift(1)), abs(data.low - data.close.shift(1))],axis=1).max(axis=1)
    upBand = MP + mu*QA.MA(TR, N)
    dnBand = MP + mu*QA.MA(TR, 40)
    FP = MP
    return pd.DataFrame({'MP': MP, 'TR': TR, 'upBand': upBand, 'dnBand':dnBand, 'FP':MP})

# %% [markdown]
# # 灌入数据

# %%
data = QA.QA_fetch_stock_day_adv("000001", '2018-05-01', '2019-09-10')

# %%
data.data
# Out:
#                     open   high    low  close     volume        amount
# date       code
# 2018-05-02 000001  10.97  11.03  10.80  10.88  1190523.0  1.295804e+09
# 2018-05-03 000001  10.86  10.88  10.57  10.75  1281355.0  1.372765e+09
# 2018-05-04 000001  10.73  10.83  10.66  10.68   710508.0  7.613020e+08
# 2018-05-07 000001  10.70  10.83  10.64  10.81   974308.0  1.046743e+09
# 2018-05-08 000001  10.83  11.15  10.80  11.01  1373305.0  1.511546e+09
# ...                  ...    ...    ...    ...        ...           ...
# 2019-09-04 000001  14.32  14.50  14.31  14.44   973964.0  1.404037e+09
# 2019-09-05 000001  14.56  14.85  14.55  14.58  1768051.0  2.599478e+09
# 2019-09-06 000001  14.71  14.81  14.62  14.81   986432.0  1.451265e+09
# 2019-09-09 000001  14.98  15.00  14.60  14.69  1299839.0  1.918042e+09
# 2019-09-10 000001  14.60  14.64  14.41  14.55   796870.0  1.155181e+09
#
# [336 rows x 6 columns]

# %%
ind = data.add_func(strategy001)
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\QUANTAXIS\QAData\base_datastruct.py:841: FutureWarning: The `squeeze` parameter is deprecated and will be removed in a future version.
#   return self.data.groupby(

# %%
ind.tail(10)
# Out:
#                           MP    TR     upBand     dnBand         FP
# date       code
# 2019-08-28 000001  14.143583  0.26  14.511583  14.511583  14.143583
# 2019-08-29 000001  14.146083  0.19  14.508833  14.508833  14.146083
# 2019-08-30 000001  14.154917  0.29  14.517417  14.517417  14.154917
# 2019-09-02 000001  14.172750  0.39  14.533250  14.533250  14.172750
# 2019-09-03 000001  14.192083  0.26  14.552333  14.552333  14.192083
# 2019-09-04 000001  14.212917  0.20  14.572917  14.572917  14.212917
# 2019-09-05 000001  14.239000  0.41  14.603000  14.603000  14.239000
# 2019-09-06 000001  14.258250  0.23  14.610750  14.610750  14.258250
# 2019-09-09 000001  14.277667  0.40  14.633167  14.633167  14.277667
# 2019-09-10 000001  14.295583  0.28  14.650833  14.650833  14.295583

# %% [markdown]
# # 实现策略

# %%
MPDIFF = ind.MP.diff().dropna()

# %%
# 在测试阶段, 我们只需要写个伪回测代码即可

# %%
lastprice = 0

for idx, item in data.iterrows():
    try:
        if MPDIFF.loc[idx]>0 and item['close']> ind.upBand.loc[idx]:
            print('buyOPEN _ {}'.format(idx))
        if MPDIFF.loc[idx]<0 and item['close']< ind.upBand.loc[idx]:
            print('sellOPEN_ {}'.format(idx))
        if lastprice< ind.FP.loc[idx] and item['close']> ind.FP.loc[idx]:
            print('close')
        if lastprice> ind.FP.loc[idx] and item['close']< ind.FP.loc[idx]:
            print('close')
    except:
        pass
    lastprice = item['close']
# Out:
# sellOPEN_ (Timestamp('2018-06-28 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-06-29 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-02 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-03 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-04 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-05 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-06 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-09 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-10 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-11 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-12 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-13 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-16 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-17 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-18 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-19 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-20 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-23 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-24 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-25 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-26 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-27 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-07-30 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2018-07-31 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-01 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2018-08-02 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-03 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-06 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-07 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-08 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-09 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2018-08-10 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-13 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2018-08-14 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-15 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-16 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-17 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-08-20 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2018-08-21 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-08-22 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-08-23 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-08-24 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-08-27 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-08-28 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-08-29 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-08-30 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-08-31 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-03 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-04 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-05 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-06 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-07 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-10 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-11 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-12 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-13 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-14 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-18 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-19 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-20 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-21 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-25 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-26 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-27 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-09-28 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-08 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-09 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-10 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2018-10-12 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2018-10-16 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-19 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2018-10-22 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-23 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-24 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-25 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-26 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-29 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-30 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-10-31 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-11-01 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-11-02 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-11-05 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2018-11-08 00:00:00'), '000001')
# close
# close
# close
# close
# sellOPEN_ (Timestamp('2018-11-26 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-11-27 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-11-28 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-11-29 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-11-30 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-05 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-10 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-11 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-12 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-14 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-17 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-18 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-19 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-20 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-21 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-24 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-25 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-26 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-27 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2018-12-28 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-01-02 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-01-03 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-01-04 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-01-07 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-01-08 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-01-09 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-01-10 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2019-01-11 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-01-14 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-01-15 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-01-17 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-01-23 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-01-24 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-01-25 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-01-28 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-01-29 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-01-30 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-01-31 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-01 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-11 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-12 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-13 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-14 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-15 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-18 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-19 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-20 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-21 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-22 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-25 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-26 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-27 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-02-28 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-01 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-04 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-05 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-06 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-07 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-08 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-11 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-12 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-13 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-14 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-15 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-18 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-19 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-20 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-21 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-22 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-27 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-03-29 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-01 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-02 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-03 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-04 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-08 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-09 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-10 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-11 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-12 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-15 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-16 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-17 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-18 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-19 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-22 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-23 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-24 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-25 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-26 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-29 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-04-30 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-06 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2019-05-07 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-08 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-09 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-13 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-17 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-20 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-21 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-22 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-23 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-30 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-05-31 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-03 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-04 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-05 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-06 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-10 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-11 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-12 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-13 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-14 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-17 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-18 00:00:00'), '000001')
# sellOPEN_ (Timestamp('2019-06-19 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2019-07-01 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-02 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-03 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-04 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-05 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-08 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-09 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-10 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-11 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-12 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-15 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-16 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-17 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-18 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-19 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-22 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-23 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-24 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-25 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-26 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-29 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-30 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-07-31 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-08-01 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2019-08-08 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2019-08-09 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-08-12 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-08-13 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-08-14 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-08-15 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-08-16 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-08-19 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-08-20 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-08-23 00:00:00'), '000001')
# close
# close
# close
# buyOPEN _ (Timestamp('2019-09-06 00:00:00'), '000001')
# buyOPEN _ (Timestamp('2019-09-09 00:00:00'), '000001')

# %%
user = QA.QA_User(username='quantaxiss', password='quantaxis')
portfolio = user.new_portfolio('strategy101')

# %%
acc.hold_available.get('2018-05-03 00:00:00',0)
# Out:
# 0

# %%
ac_hold = acc.hold_available

# %%
ac_hold.

# %%
data.index[1]
# Out:
# (Timestamp('2018-05-03 00:00:00'), '000001')

# %%
# acc = portfolio.new_account(account_cookie='acc001', init_hold={'000001':0}, init_cash=30000, market_type=QA.MARKET_TYPE.STOCK_CN)
acc = portfolio.new_account(account_cookie='acc001', init_hold={'RBL8':0}, init_cash=30000, market_type=QA.MARKET_TYPE.FUTURE_CN)
lastprice = 0

for idx, item in data.iterrows():
    try:
        if acc.hold_available.get(idx[1],0) ==0 and MPDIFF.loc[idx]>0 and item['close']> ind.upBand.loc[idx]:
            print('buyOPEN _ {}'.format(idx))
            acc.receive_simpledeal(
                code= idx[1],
                trade_price = item['close'],
                trade_amount = 1,
                trade_towards= QA.ORDER_DIRECTION.BUY_OPEN,
                trade_time= idx[0])
        if acc.hold_available.get(idx[1],0) ==0 and MPDIFF.loc[idx]<0 and item['close']< ind.upBand.loc[idx]:
            print('sellOPEN_ {}'.format(idx))
            acc.receive_simpledeal(
                code= idx[1],
                trade_price = item['close'],
                trade_amount = 1,
                trade_towards= QA.ORDER_DIRECTION.SELL_OPEN,
                trade_time= idx[0])
        if lastprice< ind.FP.loc[idx] and item['close']> ind.FP.loc[idx]:
            print('close')
            if acc.hold_available.get(idx[1],0)>0:
                #多单止盈
                acc.receive_simpledeal(
                    code= idx[1],
                    trade_price = item['close'],
                    trade_amount = 1,
                    trade_towards= QA.ORDER_DIRECTION.SELL_CLOSE,
                    trade_time= idx[0])
            elif acc.hold_available.get(idx[1],0)<0:
                # 空单止损
                acc.receive_simpledeal(
                    code= idx[1],
                    trade_price = item['close'],
                    trade_amount = 1,
                    trade_towards= QA.ORDER_DIRECTION.BUY_CLOSE,
                    trade_time= idx[0])
                
        if lastprice> ind.FP.loc[idx] and item['close']< ind.FP.loc[idx]:
            print('close')
            if acc.hold_available.get(idx[1],0)>0:
                #多单止损
                acc.receive_simpledeal(
                    code= idx[1],
                    trade_price = item['close'],
                    trade_amount = 1,
                    trade_towards= QA.ORDER_DIRECTION.SELL_CLOSE,
                    trade_time= idx[0])
            elif acc.hold_available.get(idx[1],0)<0:
                # 空单止盈
                acc.receive_simpledeal(
                    code= idx[1],
                    trade_price = item['close'],
                    trade_amount = 1,
                    trade_towards= QA.ORDER_DIRECTION.BUY_CLOSE,
                    trade_time= idx[0])
    except:
        pass
    lastprice = item['close']
# Out:
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# QAACCOUNT: THIS ACCOUNT DOESNOT HAVE ANY TRADE
# sellOPEN_ (Timestamp('2018-06-28 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2018-07-31 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2018-08-02 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2018-08-10 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2018-08-14 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2018-08-21 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2018-10-12 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2018-10-16 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2018-10-22 00:00:00'), '000001')
# close
# close
# close
# close
# sellOPEN_ (Timestamp('2018-11-26 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2019-01-11 00:00:00'), '000001')
# close
# sellOPEN_ (Timestamp('2019-05-07 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2019-07-01 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2019-08-08 00:00:00'), '000001')
# close
# buyOPEN _ (Timestamp('2019-08-09 00:00:00'), '000001')
# close
# close
# close
# buyOPEN _ (Timestamp('2019-09-06 00:00:00'), '000001')

# %%
acc.history_table
# Out:
#                datetime    code  price  amount         cash order_id  \
# 0   2018-06-28 00:00:00  000001   8.92    -1.0  29991.07108     None
# 1   2018-07-30 00:00:00  000001   9.39     1.0  29999.51169     None
# 2   2018-07-31 00:00:00  000001   9.42    -1.0  29990.08227     None
# 3   2018-08-01 00:00:00  000001   9.15     1.0  29999.76312     None
# 4   2018-08-02 00:00:00  000001   8.94    -1.0  29990.81418     None
# 5   2018-08-09 00:00:00  000001   9.29     1.0  29999.39489     None
# 6   2018-08-10 00:00:00  000001   9.23    -1.0  29990.15566     None
# 7   2018-08-13 00:00:00  000001   9.05     1.0  29999.55661     None
# 8   2018-08-14 00:00:00  000001   9.00    -1.0  29990.54761     None
# 9   2018-08-20 00:00:00  000001   9.00     1.0  29999.53861     None
# 10  2018-08-21 00:00:00  000001   9.23    -1.0  29990.29938     None
# 11  2018-10-11 00:00:00  000001   9.86     1.0  29998.88952     None
# 12  2018-10-12 00:00:00  000001  10.30     1.0  29988.57922     None
# 13  2018-10-12 00:00:00  000001  10.30    -1.0  29998.86892     None
# 14  2018-10-16 00:00:00  000001  10.37     1.0  29988.48855     None
# 15  2018-10-19 00:00:00  000001  10.76    -1.0  29999.23779     None
# 16  2018-10-22 00:00:00  000001  11.15     1.0  29988.07664     None
# 17  2018-11-15 00:00:00  000001  10.62    -1.0  29998.68602     None
# 18  2018-11-26 00:00:00  000001  10.34    -1.0  29988.33568     None
# 19  2019-01-10 00:00:00  000001  10.10     1.0  29998.90558     None
# 20  2019-01-11 00:00:00  000001  10.20    -1.0  29988.69538     None
# 21  2019-05-06 00:00:00  000001  12.87     1.0  29996.21251     None
# 22  2019-05-07 00:00:00  000001  12.95    -1.0  29983.24956     None
# 23  2019-06-19 00:00:00  000001  13.07     1.0  29996.06649     None
# 24  2019-07-01 00:00:00  000001  13.93     1.0  29982.12256     None
# 25  2019-08-05 00:00:00  000001  13.35    -1.0  29995.45921     None
# 26  2019-08-08 00:00:00  000001  14.38     1.0  29981.06483     None
# 27  2019-08-08 00:00:00  000001  14.38    -1.0  29995.43045     None
# 28  2019-08-09 00:00:00  000001  14.52     1.0  29980.89593     None
# 29  2019-08-29 00:00:00  000001  14.13    -1.0  29995.01180     None
# 30  2019-09-06 00:00:00  000001  14.81     1.0  29980.18699     None
#
#    realorder_id trade_id account_cookie  commission  tax message  frozen  \
# 0          None     None         acc001     0.00892    0    None    8.92
# 1          None     None         acc001     0.00939    0    None    0.00
# 2          None     None         acc001     0.00942    0    None    9.42
# 3          None     None         acc001     0.00915    0    None    0.00
# 4          None     None         acc001     0.00894    0    None    8.94
# 5          None     None         acc001     0.00929    0    None    0.00
# 6          None     None         acc001     0.00923    0    None    9.23
# 7          None     None         acc001     0.00905    0    None    0.00
# 8          None     None         acc001     0.00900    0    None    9.00
# 9          None     None         acc001     0.00900    0    None    0.00
# 10         None     None         acc001     0.00923    0    None    9.23
# 11         None     None         acc001     0.00986    0    None    0.00
# 12         None     None         acc001     0.01030    0    None   10.30
# 13         None     None         acc001     0.01030    0    None    0.00
# 14         None     None         acc001     0.01037    0    None   10.37
# 15         None     None         acc001     0.01076    0    None    0.00
# 16         None     None         acc001     0.01115    0    None   11.15
# 17         None     None         acc001     0.01062    0    None    0.00
# 18         None     None         acc001     0.01034    0    None   10.34
# 19         None     None         acc001     0.01010    0    None    0.00
# 20         None     None         acc001     0.01020    0    None   10.20
# 21         None     None         acc001     0.01287    0    None    0.00
# 22         None     None         acc001     0.01295    0    None   12.95
# 23         None     None         acc001     0.01307    0    None    0.00
# 24         None     None         acc001     0.01393    0    None   13.93
# 25         None     None         acc001     0.01335    0    None    0.00
# 26         None     None         acc001     0.01438    0    None   14.38
# 27         None     None         acc001     0.01438    0    None    0.00
# 28         None     None         acc001     0.01452    0    None   14.52
# 29         None     None         acc001     0.01413    0    None    0.00
# 30         None     None         acc001     0.01481    0    None   14.81
#
#     direction  total_frozen
# 0          -2          8.92
# 1           3          0.00
# 2          -2          9.42
# 3           3          0.00
# 4          -2          8.94
# 5           3          0.00
# 6          -2          9.23
# 7           3          0.00
# 8          -2          9.00
# 9           3          0.00
# 10         -2          9.23
# 11          3          0.00
# 12          2         10.30
# 13         -3          0.00
# 14          2         10.37
# 15         -3          0.00
# 16          2         11.15
# 17         -3          0.00
# 18         -2         10.34
# 19          3          0.00
# 20         -2         10.20
# 21          3          0.00
# 22         -2         12.95
# 23          3          0.00
# 24          2         13.93
# 25         -3          0.00
# 26          2         14.38
# 27         -3          0.00
# 28          2         14.52
# 29         -3          0.00
# 30          2         14.81

# %%
performance = QA.QA_Performance(acc)

# %%
performance.pnl_fifo
# Out:
#         sell_date   buy_date  amount  sell_price  buy_price rawdirection  \
# code
# 000001 2018-06-28 2018-07-30     1.0        8.92       9.39         sell
# 000001 2018-07-31 2018-08-01     1.0        9.42       9.15         sell
# 000001 2018-08-02 2018-08-09     1.0        8.94       9.29         sell
# 000001 2018-08-10 2018-08-13     1.0        9.23       9.05         sell
# 000001 2018-08-14 2018-08-20     1.0        9.00       9.00         sell
# 000001 2018-08-21 2018-10-11     1.0        9.23       9.86         sell
# 000001 2018-10-12 2018-10-12     1.0       10.30      10.30          buy
# 000001 2018-10-19 2018-10-16     1.0       10.76      10.37          buy
# 000001 2018-11-15 2018-10-22     1.0       10.62      11.15          buy
# 000001 2018-11-26 2019-01-10     1.0       10.34      10.10         sell
# 000001 2019-01-11 2019-05-06     1.0       10.20      12.87         sell
# 000001 2019-05-07 2019-06-19     1.0       12.95      13.07         sell
# 000001 2019-08-05 2019-07-01     1.0       13.35      13.93          buy
# 000001 2019-08-08 2019-08-08     1.0       14.38      14.38          buy
# 000001 2019-08-29 2019-08-09     1.0       14.13      14.52          buy
#
#         unit  pnl_ratio  pnl_money hold_gap  if_buyopen  openprice  \
# code
# 000001   1.0  -0.050053      -0.47  32 days       False       8.92
# 000001   1.0   0.029508       0.27   1 days       False       9.42
# 000001   1.0  -0.037675      -0.35   7 days       False       8.94
# 000001   1.0   0.019890       0.18   3 days       False       9.23
# 000001   1.0   0.000000       0.00   6 days       False       9.00
# 000001   1.0  -0.063895      -0.63  51 days       False       9.23
# 000001   1.0   0.000000       0.00   0 days        True      10.30
# 000001   1.0   0.037608       0.39   3 days        True      10.37
# 000001   1.0  -0.047534      -0.53  24 days        True      11.15
# 000001   1.0   0.023762       0.24  45 days       False      10.34
# 000001   1.0  -0.207459      -2.67 115 days       False      10.20
# 000001   1.0  -0.009181      -0.12  43 days       False      12.95
# 000001   1.0  -0.041637      -0.58  35 days        True      13.93
# 000001   1.0   0.000000       0.00   0 days        True      14.38
# 000001   1.0  -0.026860      -0.39  20 days        True      14.52
#
#                    opendate  closeprice            closedate
# code
# 000001  2018-06-28 00:00:00        9.39  2018-07-30 00:00:00
# 000001  2018-07-31 00:00:00        9.15  2018-08-01 00:00:00
# 000001  2018-08-02 00:00:00        9.29  2018-08-09 00:00:00
# 000001  2018-08-10 00:00:00        9.05  2018-08-13 00:00:00
# 000001  2018-08-14 00:00:00        9.00  2018-08-20 00:00:00
# 000001  2018-08-21 00:00:00        9.86  2018-10-11 00:00:00
# 000001  2018-10-12 00:00:00       10.30  2018-10-12 00:00:00
# 000001  2018-10-16 00:00:00       10.76  2018-10-19 00:00:00
# 000001  2018-10-22 00:00:00       10.62  2018-11-15 00:00:00
# 000001  2018-11-26 00:00:00       10.10  2019-01-10 00:00:00
# 000001  2019-01-11 00:00:00       12.87  2019-05-06 00:00:00
# 000001  2019-05-07 00:00:00       13.07  2019-06-19 00:00:00
# 000001  2019-07-01 00:00:00       13.35  2019-08-05 00:00:00
# 000001  2019-08-08 00:00:00       14.38  2019-08-08 00:00:00
# 000001  2019-08-09 00:00:00       14.13  2019-08-29 00:00:00

# %%
acc.market_type
# Out:
# 'future_cn'

# %%
risk = QA.QA_Risk(acc)
# Out:
# margin!

# %%
# 用市价计算的每日总资产
(risk.daily_market_value+ acc.daily_cash.cash).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# 用冻结保证金计算的总资产

(acc.daily_frozen+ acc.daily_cash.cash).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
risk.plot_assets_curve()
# Out:
# <module 'matplotlib.pyplot' from 'd:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
risk.save()
acc.save()
