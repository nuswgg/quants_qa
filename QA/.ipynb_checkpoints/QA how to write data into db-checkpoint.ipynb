# %%
from QUANTAXIS.QAUtil import QASETTING

# %%
client = QASETTING.client

# %%
qa_db = client.get_database('quantaxis')

# %%
Engine = client.get_database('quantaxis')

# %%
Engine.QA_fetch_get_stock_day('000001','2025-05-23','2026-07-03')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-aa0c46d232eb> in <module>
# ----> 1 Engine.QA_fetch_get_stock_day('000001','2025-05-23','2026-07-03')
#
# d:\ProgramData\Anaconda3\lib\site-packages\pymongo\collection.py in __call__(self, *args, **kwargs)
#    3438         """
#    3439         if "." not in self.__name:
# -> 3440             raise TypeError("'Collection' object is not callable. If you "
#    3441                             "meant to call the '%s' method on a 'Database' "
#    3442                             "object it is failing because no such method "
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'QA_fetch_get_stock_day' method on a 'Database' object it is failing because no such method exists.

# %%
index_data = qa_db.get_collection('index_list')

# %%
#获得模型数据库的链接
model_db = client.get_database('model')

# %%
# 创建表
# model_db.create_collection('stock_ma')
# model_db.create_collection('stock_kline')
# model_db.create_collection('stock_vol')

# model_db.create_collection('block_ma')
# model_db.create_collection('block_kline')
# model_db.create_collection('block_vol')

# model_db.create_collection('index_ma')
# model_db.create_collection('index_kline')
# model_db.create_collection('index_vol')

# %%
ma_coll = model_db.get_collection('stock_ma')

# %%
# stock
ma 5,10,15,20,30,40,60,80,120,240
#store kline
kline: 
#vol
