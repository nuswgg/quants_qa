# %%
conf = {
    'zig':{'zig1':0.2/100,'zig2':0.3/100,'zig3':0.5/100,'zig4':0.8/100, 'zig5':1.3/100 ,'zig6': 2.1/100},
    'ma':{'m0':3,'m1':6,'m2':12,'m3':24,'m4':48,'m5':96,'m6':192,'m7':384}
            }

# %%
conf
# Out:
# {'zig': {'zig1': 0.002,
#   'zig2': 0.003,
#   'zig3': 0.005,
#   'zig4': 0.008,
#   'zig5': 0.013000000000000001,
#   'zig6': 0.021},
#  'ma': {'m0': 3,
#   'm1': 6,
#   'm2': 12,
#   'm3': 24,
#   'm4': 48,
#   'm5': 96,
#   'm6': 192,
#   'm7': 384}}

# %%
para = {'K线':{
            '中阴': 1.3,
            '大阴': 2,
            '中阳': 1.3,
            '大阳': 2,
            },
        'bsp':{
            'relative_yc':3 #bsp/bsp.shift(1)
            },
        'volume': {
            'fl_v1_strength': 1
            },
        'stop_loss': {
            'long': {'buffer_ratio': 2}, # 用于乘ma_body 用于buffer
            'short': {}
            }
       }
