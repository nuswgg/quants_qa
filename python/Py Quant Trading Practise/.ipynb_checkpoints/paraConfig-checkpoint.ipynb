# %%
conf = {
    'zig':{'zig1':0.18/100,'zig2':0.3/100,'zig3':0.5/100,'zig4':0.8/100, 'zig5':1.3/100 ,'zig6': 2.1/100},
    'zone':{'z1':2,'z2':2.5,'z3':3,'z4':3.5,'z5':4.2,'z6':5},
    'ma':{'m0':3,'m1':6,'m2':12,'m3':24,'m4':48,'m5':96,'m6':192,'m7':384}
            }

# %%
thresh_td = [conf['zig']['zig6']/conf['zone']['z6'],conf['zig']['zig5']/conf['zone']['z5'],\
    conf['zig']['zig4']/conf['zone']['z4'],conf['zig']['zig3']/conf['zone']['z3']\
    ,conf['zig']['zig2']/conf['zone']['z2'],conf['zig']['zig1']/conf['zone']['z1']]
print(thresh_td)
# Out:
# [0.004200000000000001, 0.0030952380952380953, 0.002285714285714286, 0.0016666666666666668, 0.0012000000000000001, 0.0009]

# %% [markdown]
# # conf

# %%
para = {'K线':{
            '中阴': -1.2,
            '大阴': -2,
            '中阳': 1.2,
            '大阳': 2,
            },
        'bsp':{
            'relative_yc':3 #bsp/bsp.shift(1)
            },
        'volume': {
            'fl_v1_strength': 1
            },
        'stop_loss': {
            'long': {'buffer_ratio': 2}, # 用于乘ma_body 用于buffer
            'short': {}
            },
        'bsp': {'yc_ratio':3}
       }

# %%
# 空头 1
# 空头震荡 2
# 空转多 3
# 多头 4
# 多头震荡 5
# 多转空 6
