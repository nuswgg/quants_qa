# %%
from xtquant import xtdata

# 1. 下载并更新板块分类数据
xtdata.download_sector_data()

# 2. 获取所有可用的板块列表（包含行业、概念、地域等）
sector_list = xtdata.get_sector_list()
print("部分板块列表:", sector_list[:5])

# 3. 获取指定板块（如沪深300）的成分股列表
stock_codes = xtdata.get_stock_list_in_sector("沪深300")
print("沪深300成分股示例:", stock_codes[:5])
# Out:
# xtquant文档地址：http://dict.thinktrader.net/nativeApi/start_now.html
# ***** xtdata连接成功 2026-07-04 22:37:09*****
# 服务信息: {'tag': 'sp3', 'version': '1.0'}
# 服务地址: 127.0.0.1:58610
# 数据路径: D:\国金QMT交易端模拟\bin.x64/../userdata_mini/datadir
# 设置xtdata.enable_hello = False可隐藏此消息
#
# 部分板块列表: ['上期所', '上证A股', '上证B股', '上证期权', '上证转债']
# 沪深300成分股示例: ['600000.SH', '600009.SH', '600010.SH', '600011.SH', '600015.SH']

# %%
sector_list[sector_list.like('GICS3*')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-d4f084f761ea> in <module>
# ----> 1 sector_list[sector_list.like('GICS3*')]
#
# AttributeError: 'list' object has no attribute 'like'

# %%
[s for s in sector_list if s.startswith("GICS2")]
# Out:
# ['GICS2保险',
#  'GICS2公用事业',
#  'GICS2制药、生物科技和生命科学',
#  'GICS2医疗保健设备与服务',
#  'GICS2半导体产品与设备',
#  'GICS2原材料',
#  'GICS2商业和专业服务',
#  'GICS2媒体与娱乐',
#  'GICS2家庭与个人用品',
#  'GICS2房地产管理和开发',
#  'GICS2技术硬件与设备',
#  'GICS2日常消费品经销与零售',
#  'GICS2汽车与汽车零部件',
#  'GICS2消费者服务',
#  'GICS2电信业务',
#  'GICS2耐用消费品与服装',
#  'GICS2能源',
#  'GICS2资本品',
#  'GICS2软件与服务',
#  'GICS2运输',
#  'GICS2金融服务',
#  'GICS2银行',
#  'GICS2非必需消费品经销与零售业',
#  'GICS2食品、饮料与烟草']

# %%
stock_codes = xtdata.get_stock_list_in_sector("GICS2食品、饮料与烟草")

# %%
stock_codes
# Out:
# ['00073.HK',
#  '00142.HK',
#  '00168.HK',
#  '00220.HK',
#  '00236.HK',
#  '00288.HK',
#  '00291.HK',
#  '00322.HK',
#  '00345.HK',
#  '00374.HK',
#  '00389.HK',
#  '00411.HK',
#  '00472.HK',
#  '00506.HK',
#  '00660.HK',
#  '00682.HK',
#  '00756.HK',
#  '00809.HK',
#  '00828.HK',
#  '00829.HK',
#  '00834.HK',
#  '00841.HK',
#  '00875.HK',
#  '00926.HK',
#  '00969.HK',
#  '01068.HK',
#  '01112.HK',
#  '01115.HK',
#  '01117.HK',
#  '01203.HK',
#  '01262.HK',
#  '01285.HK',
#  '01340.HK',
#  '01364.HK',
#  '01431.HK',
#  '01432.HK',
#  '01446.HK',
#  '01458.HK',
#  '01475.HK',
#  '01533.HK',
#  '01579.HK',
#  '01583.HK',
#  '01610.HK',
#  '01676.HK',
#  '01695.HK',
#  '01699.HK',
#  '01717.HK',
#  '01767.HK',
#  '01837.HK',
#  '01876.HK',
#  '01886.HK',
#  '01927.HK',
#  '02097.HK',
#  '02119.HK',
#  '02147.HK',
#  '02218.HK',
#  '02226.HK',
#  '02317.HK',
#  '02319.HK',
#  '02419.HK',
#  '02425.HK',
#  '02460.HK',
#  '02497.HK',
#  '02517.HK',
#  '02555.HK',
#  '02589.HK',
# ...

# %%
[s for s in sector_list if s.startswith("GICS3")]
# Out:
# ['GICS3专业服务',
#  'GICS3专营零售',
#  'GICS3个人护理用品',
#  'GICS3互动媒体与服务',
#  'GICS3交通基本设施',
#  'GICS3休闲设备与用品',
#  'GICS3保险',
#  'GICS3信息技术服务',
#  'GICS3制药',
#  'GICS3化学制品',
#  'GICS3医疗保健技术',
#  'GICS3医疗保健提供商与服务',
#  'GICS3医疗保健设备与用品',
#  'GICS3半导体产品与设备',
#  'GICS3商业服务与商业用品',
#  'GICS3商业银行',
#  'GICS3地面运输',
#  'GICS3复合型公用事业',
#  'GICS3多品类零售',
#  'GICS3娱乐',
#  'GICS3媒体',
#  'GICS3客运航空公司',
#  'GICS3家庭耐用消费品',
#  'GICS3容器与包装',
#  'GICS3居家用品',
#  'GICS3工业集团企业',
#  'GICS3建筑与工程',
#  'GICS3建筑产品',
#  'GICS3建筑材料',
#  'GICS3房地产管理和开发',
#  'GICS3抵押房地产投资信托(REITs)',
#  'GICS3无线电信业务',
#  'GICS3日常消费品经销与零售',
#  'GICS3机械制造',
#  'GICS3水公用事业',
#  'GICS3汽车',
#  'GICS3汽车零部件',
#  'GICS3海上运输',
#  'GICS3消费信贷',
#  'GICS3烟草',
#  'GICS3燃气公用事业',
#  'GICS3独立电力生产商与能源贸易商',
#  'GICS3生命科学工具和服务',
#  'GICS3生物科技',
#  'GICS3电力公用事业',
#  'GICS3电子设备、仪器和元件',
#  'GICS3电气设备',
#  'GICS3电脑与外围设备',
#  'GICS3石油、天然气与消费用燃料',
#  'GICS3纸类与林业产品',
#  'GICS3纺织品、服装与奢侈品',
#  'GICS3经销商',
#  'GICS3综合消费者服务',
#  'GICS3综合电信业务',
#  'GICS3能源设备与服务',
# ...

# %%
[s for s in sector_list if s.startswith("GICS4")]
# Out:
# ['GICS4个人护理用品',
#  'GICS4互动媒体与服务',
#  'GICS4互动家庭娱乐',
#  'GICS4互联网服务与基础架构',
#  'GICS4交易与支付处理服务',
#  'GICS4人力资源与就业服务',
#  'GICS4人寿与健康保险',
#  'GICS4住宅建筑',
#  'GICS4保健护理产品经销商',
#  'GICS4保健护理服务',
#  'GICS4保健护理机构',
#  'GICS4保险经纪商',
#  'GICS4信息科技咨询与其它服务',
#  'GICS4公路与铁路',
#  'GICS4其他专卖店',
#  'GICS4再保险',
#  'GICS4农产品与服务',
#  'GICS4农用农业机械',
#  'GICS4出版',
#  'GICS4制药',
#  'GICS4办公服务与用品',
#  'GICS4包装食品与肉类',
#  'GICS4化肥与农用药剂',
#  'GICS4区域性银行',
#  'GICS4医疗保健技术',
#  'GICS4医疗保健用品',
#  'GICS4医疗保健设备',
#  'GICS4半导体产品',
#  'GICS4半导体材料与设备',
#  'GICS4商业与住宅抵押贷款金融',
#  'GICS4商业印刷',
#  'GICS4商品化工',
#  'GICS4啤酒酿造商',
#  'GICS4地面客运',
#  'GICS4地面货运',
#  'GICS4复合型公用事业',
#  'GICS4多元化保险',
#  'GICS4多元化房地产业务',
#  'GICS4多品类零售',
#  'GICS4多种化学制品',
#  'GICS4多种金属与采矿',
#  'GICS4多领域控股',
#  'GICS4安全和报警服务',
#  'GICS4客运航空公司',
#  'GICS4家庭装潢零售',
#  'GICS4家庭装饰品',
#  'GICS4家庭装饰零售',
#  'GICS4家用器具与特殊消费品',
#  'GICS4家用电器',
#  'GICS4居家用品',
#  'GICS4工业机械、物料与部件',
#  'GICS4工业气体',
#  'GICS4工业集团企业',
#  'GICS4广告',
#  'GICS4广播',
# ...

# %%
xtdata.get_stock_list_in_sector("GICS4黄金")
# Out:
# ['00340.HK',
#  '00621.HK',
#  '01712.HK',
#  '01787.HK',
#  '01818.HK',
#  '02099.HK',
#  '02899.HK',
#  '02919.HK',
#  '02937.HK',
#  '02949.HK',
#  '02956.HK',
#  '02980.HK',
#  '03330.HK',
#  '06181.HK',
#  '06693.HK',
#  '08299.HK',
#  '08371.HK',
#  '08393.HK',
#  '08551.HK',
#  '08565.HK',
#  '08575.HK',
#  '600311.SH',
#  '600489.SH',
#  '600547.SH',
#  '600687.SH',
#  '600916.SH',
#  '600988.SH',
#  '601028.SH',
#  '601069.SH',
#  '601899.SH',
#  '000506.SZ',
#  '001337.SZ',
#  '002155.SZ',
#  '002237.SZ',
#  '300139.SZ']
