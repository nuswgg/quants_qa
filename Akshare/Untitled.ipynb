# %%
import akshare as ak

# %%
ak.stock_zh_ah_spot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:03<00:00,  2.50it/s]
#         代码      名称     最新价     涨跌幅     涨跌额      买入      卖出         成交量  \
# 0    01211   比亚迪股份  265.00    1.07    2.80  265.00  265.00  8436218.00
# 1    01880    中国中免  164.40    4.05    6.40  164.40  164.40  2795933.00
# 2    06821     凯莱英  110.40   -0.45   -0.50  110.40  110.40   298280.00
# 3    06160    百济神州  109.10    1.21    1.30  109.10  109.10  1957539.00
# 4    02359    药明康德   90.45    2.78    2.45   90.45   90.45  2769573.00
# ..     ...     ...     ...     ...     ...     ...     ...         ...
# 144  01053  重庆钢铁股份    0.90    0.00    0.00    0.90    0.90  1574000.00
# 145  02880    辽港股份    0.71   -1.39   -0.01    0.71    0.71  1096000.00
# 146  01033   中石化油服    0.53   -1.85   -0.01    0.53    0.53  8762000.00
# 147  00042    东北电气   0.370  -1.330  -0.005   0.370   0.370  342000.000
# ...

# %%
stock_zh_a_spot_df = ak.stock_zh_a_spot()
# Out:
# Please wait for a moment: 100%|████████████████████████████████████████████████████████| 62/62 [00:36<00:00,  1.68it/s]

# %%
stock_zh_a_spot_df.columns
# Out:
# Index(['symbol', 'code', 'name', 'trade', 'pricechange', 'changepercent',
#        'buy', 'sell', 'settlement', 'open', 'high', 'low', 'volume', 'amount',
#        'ticktime', 'per', 'pb', 'mktcap', 'nmc', 'turnoverratio'],
#       dtype='object')

# %%
stock_zh_a_spot_df.shape
# Out:
# (4885, 20)

# %%
stock_zh_a_spot_df.filter(['symbol', 'code', 'name','mktcap']).sort_values(by='mktcap',ascending=False)
# Out:
#         symbol    code  name        mktcap
# 508   sh600519  600519  贵州茅台  2.384263e+08
# 991   sh601398  601398  工商银行  1.550367e+08
# 855   sh600941  600941  中国移动  1.392215e+08
# 1088  sh601939  601939  建设银行  1.367560e+08
# 4429  sz300750  300750  宁德时代  1.236782e+08
# ...        ...     ...   ...           ...
# 24    bj831856  831856  浩淼科技  4.300373e+04
# 55    bj834765  834765   美之高  4.058440e+04
# 28    bj832145  832145  恒合股份  4.035460e+04
# 67    bj836149  836149  旭杰科技  3.577263e+04
# 62    bj835508  835508  殷图网联  3.440000e+04
#
# [4885 rows x 4 columns]

# %%
dir(ak)
# Out:
# ['__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_get_code_pic',
#  'agoyal_stock_return',
#  'air',
#  'air_city_list',
#  'air_quality_hebei',
#  'air_quality_hist',
#  'air_quality_rank',
#  'air_quality_watch_point',
#  'amac_aoin_info',
#  'amac_fund_abs',
#  'amac_fund_account_info',
#  'amac_fund_info',
#  'amac_fund_sub_info',
#  'amac_futures_info',
#  'amac_manager_cancelled_info',
#  'amac_manager_classify_info',
#  'amac_manager_info',
#  'amac_member_info',
#  'amac_member_sub_info',
#  'amac_person_org_list',
#  'amac_securities_info',
#  'article',
#  'article_epu_index',
#  'article_ff_crr',
#  'article_oman_rv',
#  'article_oman_rv_short',
#  'article_rlab_rv',
#  'baidu_info_index',
#  'baidu_media_index',
#  'baidu_search_index',
#  'bank',
#  'bank_fjcf_table_detail',
#  'bank_rank_banker',
#  'bond',
#  'bond_china_close_return',
# ...
