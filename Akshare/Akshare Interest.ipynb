# %%
import akshare as ak

# %%
us_interst = ak.macro_bank_usa_interest_rate()

# %%
us_interst['1999-01-01':].plot()
# Out:
# <AxesSubplot:>

# %%
eu_interest = ak.macro_bank_euro_interest_rate()
eu_interest.plot()
# Out:
# <AxesSubplot:>

# %%
nz_interest =  ak.macro_bank_newzealand_interest_rate()
nz_interest
# Out:
# 1999-04-01    4.50
# 1999-05-01    4.50
# 1999-06-01    4.50
# 1999-07-01    4.50
# 1999-08-01    4.50
#               ...
# 2023-02-22    4.75
# 2023-04-05    5.25
# 2023-05-24    5.50
# 2023-07-12    5.50
# 2023-08-16    5.50
# Name: newzealand_interest_rate, Length: 224, dtype: float64

# %%
nz_interest.plot()
# Out:
# <AxesSubplot:>

# %%
uk_interest = ak.macro_bank_english_interest_rate()
uk_interest
# Out:
# 1970-01-01    8.00
# 1970-02-01    8.00
# 1970-03-01    8.00
# 1970-04-01    7.50
# 1970-05-01    7.00
#               ...
# 2023-02-02    4.00
# 2023-03-23    4.25
# 2023-05-11    4.50
# 2023-06-22    5.00
# 2023-08-03    5.25
# Name: english_interest_rate, Length: 618, dtype: float64

# %%
uk_interest.loc['1999-01-01':].plot()
# Out:
# <AxesSubplot:>

# %%
au_interest = ak.macro_bank_australia_interest_rate()
au_interest
# Out:
# 1980-02-01     7.92
# 1980-03-01     8.20
# 1980-04-01     9.25
# 1980-05-01     8.98
# 1980-06-01    10.74
#               ...
# 2023-04-04     3.60
# 2023-05-02     3.85
# 2023-06-06     4.10
# 2023-07-04     4.10
# 2023-08-01     4.10
# Name: australia_interest_rate, Length: 504, dtype: float64

# %%
au_interest.loc['1999-01-01':].plot()
# Out:
# <AxesSubplot:>

# %%
jp_interest = ak.macro_bank_japan_interest_rate()
jp_interest
# Out:
# 2008-02-14    0.5
# 2008-03-07    0.5
# 2008-04-09    0.5
# 2008-04-30    0.5
# 2008-06-13    0.5
#              ...
# 2023-01-18   -0.1
# 2023-03-10   -0.1
# 2023-04-28   -0.1
# 2023-06-16   -0.1
# 2023-07-28   -0.1
# Name: japan_interest_rate, Length: 173, dtype: float64

# %%
jp_interest.plot()
# Out:
# <AxesSubplot:>

# %%
ru_interest = ak.macro_bank_russia_interest_rate()
ru_interest
# Out:
# 2003-06-01     6.5
# 2003-07-01     6.5
# 2003-08-01     6.5
# 2003-09-01     6.5
# 2003-10-01     6.5
#               ...
# 2023-03-17     7.5
# 2023-04-28     7.5
# 2023-06-09     7.5
# 2023-07-21     8.5
# 2023-08-15    12.0
# Name: russia_interest_rate, Length: 209, dtype: float64

# %%
ru_interest.plot()
# Out:
# <AxesSubplot:>

# %%
in_interest = ak.macro_bank_india_interest_rate()
in_interest
# Out:
# 2000-08-01     7.375
# 2000-09-01    13.348
# 2000-10-01    10.524
# 2000-11-01     8.614
# 2000-12-01     8.000
#                ...
# 2022-12-07     6.250
# 2023-02-08     6.500
# 2023-04-06     6.500
# 2023-06-08     6.500
# 2023-08-10     6.500
# Name: india_interest_rate, Length: 219, dtype: float64

# %%
in_interest.plot()
# Out:
# <AxesSubplot:>

# %%
bra_interest = ak.macro_bank_brazil_interest_rate()
bra_interest
# Out:
# 2008-02-01    11.25
# 2008-04-01    11.25
# 2008-05-01    11.75
# 2008-07-01    12.25
# 2008-08-01    13.00
#               ...
# 2023-02-02    13.75
# 2023-03-23    13.75
# 2023-05-04    13.75
# 2023-06-22    13.75
# 2023-08-03    13.25
# Name: brazil_interest_rate, Length: 125, dtype: float64

# %%
bra_interest.plot()
# Out:
# <AxesSubplot:>

# %%
sh_rate_interbank_df = ak.rate_interbank(market="上海银行同业拆借市场", symbol="Shibor人民币", indicator="3月")
print(sh_rate_interbank_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\akshare\interest_rate\interbank_rate_em.py in _get_page_num(market, symbol, indicator)
#      41         page_num = (
# ---> 42             soup.find("div", attrs={"class": "Page"})
#      43             .find_all("a", attrs={"target": "_self"})[-1]["href"]
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
#
# During handling of the above exception, another exception occurred:
#
# IPError                                   Traceback (most recent call last)
# <ipython-input-37-01782f25dc14> in <module>
# ----> 1 sh_rate_interbank_df = ak.rate_interbank(market="上海银行同业拆借市场", symbol="Shibor人民币", indicator="3月")
#       2 print(sh_rate_interbank_df)
#
# ...

# %% [markdown]
# # 证券公司集合资管产品公示

# %%
amac_securities_info_df = ak.amac_securities_info()
# Out:
# 正在下载, 由于数据量比较大, 请等待大约 5 秒

# %%
amac_securities_info_df
# Out:
#                      产品名称    产品编码       管理人名称        成立日期        到期时间   投资类型  \
# 0       国联睿远周周盈1号集合资产管理计划  SXG556  国联证券股份有限公司  2022-09-09  2032-09-08  固定收益类
# 1     国海证券启航2951号集合资产管理计划  SXH506  国海证券股份有限公司  2022-09-09  2025-09-08  固定收益类
# 2    国海证券扬帆6个月12号集合资产管理计划  SXG677  国海证券股份有限公司  2022-09-09  2032-09-08  固定收益类
# 3    国海证券扬帆6个月11号集合资产管理计划  SXG675  国海证券股份有限公司  2022-09-09  2032-09-08  固定收益类
# 4   世纪证券融享24M003号集合资产管理计划  SXF929  世纪证券有限责任公司  2022-09-09  2032-09-08  固定收益类
# ..                    ...     ...         ...         ...         ...    ...
# 95     国元证券元赢122号集合资产管理计划  SXA236  国元证券股份有限公司  2022-08-24  2032-08-24  固定收益类
# 96   申万宏源建盈福旺金利1号集合资产管理计划  SVW214  申万宏源证券有限公司  2022-08-24  2030-08-24  固定收益类
# 97    国海证券扬帆6个月8号集合资产管理计划  SXE285  国海证券股份有限公司  2022-08-24  2032-08-23  固定收益类
# 98    国海证券扬帆月添利9号集合资产管理计划  SXB970  国海证券股份有限公司  2022-08-24  2032-08-23  固定收益类
# 99         开源开鑫5号集合资产管理计划  SXD782  开源证券股份有限公司  2022-08-24  2023-08-23  固定收益类
#
#    是否分级         托管人名称        备案日期  运作状态
# ...

# %%
len(amac_securities_info_df)
# Out:
# 100

# %% [markdown]
# # 证券公司直投基金

# %%
amac_aoin_info_df = ak.amac_aoin_info()
amac_aoin_info_df
# Out:
#       产品编码                       产品名称              直投子公司  \
# 0   S32077      深圳市远盛发展一期股权投资企业（有限合伙）    招商证券股份有限公司直投子公司
# 1   S32105       新疆华融天泽鼎鑫投资合伙企业（有限合伙）    华融证券股份有限公司直投子公司
# 2   S32073         新疆广发信德广电夹层投资有限合伙企业       广发信德投资管理有限公司
# 3   S32644       吉林省国家新材料产业创业投资有限责任公司  第一创业证券股份有限公司直投子公司
# 4   S32067           赣州致发投资合伙企业（有限合伙）    招商证券股份有限公司直投子公司
# ..     ...                        ...                ...
# 95  S32144  深圳前海新时代宏图贰号投资基金合伙企业（有限合伙）   新时代证券有限责任公司直投子公司
# 96  S32127       合肥中安润信基金投资合伙企业（有限合伙）  中信建投证券股份有限公司直投子公司
# 97  S32357         南江贵银平滑资产管理中心（有限合伙）    华创证券有限责任公司直投子公司
# 98  S32201           祺程（上海）投资中心（有限合伙）     中金智德股权投资管理有限公司
# 99  S32381             苏州临湖投资中心（有限合伙）       中银国际投资有限责任公司
#
#                     管理机构       设立日期
# 0          深圳市远盛投资管理有限公司 2012-12-26
# 1             华融天泽投资有限公司 2013-03-14
# 2       新疆广发信德稳胜投资管理有限公司 2013-03-25
# 3       北京一创吉星创业投资管理有限公司 2013-05-24
# 4         江西致远发展投资管理有限公司 2013-07-09
# ..                   ...        ...
# ...

# %% [markdown]
# # 主要央行利率

# %% [markdown]
# 美国央行利率

# %%
us_int_rate_df = ak.macro_bank_usa_interest_rate()

# %%
us_int_rate_df
# Out:
# 1982-09-27    10.25
# 1982-10-01    10.00
# 1982-10-07     9.50
# 1982-11-19     9.00
# 1982-12-14     8.50
#               ...
# 2021-12-16     0.25
# 2022-01-27     0.25
# 2022-03-17     0.50
# 2022-05-05     1.00
# 2022-06-16     1.75
# Name: usa_interest_rate, Length: 263, dtype: float64

# %%
eu_int_rate_df = ak.macro_bank_euro_interest_rate()

# %%
eu_int_rate_df
# Out:
# 1999-01-01    3.0
# 1999-02-01    3.0
# 1999-03-01    3.0
# 1999-04-01    3.0
# 1999-05-01    2.5
#              ...
# 2021-12-16    0.0
# 2022-02-03    0.0
# 2022-03-10    0.0
# 2022-04-14    0.0
# 2022-06-09    0.0
# Name: euro_interest_rate, Length: 253, dtype: float64

# %%
cn_int_rate_df = ak.macro_bank_china_interest_rate()

# %%
uk_int_rate_df = ak.macro_bank_english_interest_rate()

# %%
au_int_rate_df = ak.macro_bank_australia_interest_rate()

# %%
jp_int_rate_df = ak.macro_bank_japan_interest_rate()

# %%
import matplotlib as plt

# %%
us_int_rate_df.plot()
# Out:
# <AxesSubplot:>

# %%
cn_int_rate_df.plot()
# Out:
# <AxesSubplot:>

# %%
eu_int_rate_df.plot()
# Out:
# <AxesSubplot:>

# %%
jp_int_rate_df.plot()
# Out:
# <AxesSubplot:>

# %%
au_int_rate_df.plot()
# Out:
# <AxesSubplot:>
