# %%
import akshare as ak

# %%
# ak.stock_zh_ah_spot()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:03<00:00,  2.45it/s]
#         代码      名称     最新价     涨跌幅     涨跌额      买入      卖出         成交量  \
# 0    01211   比亚迪股份  263.00   -0.45   -1.20  263.00  263.00  8038003.00
# 1    01880    中国中免  170.00   -2.19   -3.80  170.00  170.00  1341600.00
# 2    06821     凯莱英  104.10   -0.76   -0.80  104.10  104.10   139140.00
# 3    06160    百济神州  100.50   -5.90   -6.30  100.50  100.50  1357369.00
# 4    02359    药明康德   87.30   -0.85   -0.75   87.30   87.30  2564599.00
# ..     ...     ...     ...     ...     ...     ...     ...         ...
# 144  01053  重庆钢铁股份    0.88   -1.12   -0.01    0.88    0.88  1840000.00
# 145  02880    辽港股份    0.71    0.00    0.00    0.71    0.71   520000.00
# 146  01033   中石化油服    0.53    0.00    0.00    0.53    0.53  2122000.00
# 147  00042    东北电气   0.365  -2.670  -0.010   0.365   0.365  218000.000
# 148  06116    拉夏贝尔   0.270   9.760   0.024   0.270   0.270  107200.000
#
#                成交额      今开      昨收      最高      最低
# 0    2112018379.26  269.80  264.20  270.80  259.40
# 1     228589263.65  175.00  173.80  176.80  168.00
# 2      14362284.00  106.80  104.90  106.80  101.80
# 3     137368187.00  102.90  106.80  103.10  100.20
# 4     222821765.24   87.05   88.05   88.05   85.10
# ..             ...     ...     ...     ...     ...
# 144     1603620.00    0.88    0.89    0.89    0.86
# 145      367200.00    0.70    0.71    0.71    0.70
# 146     1116460.00    0.53    0.53    0.53    0.52
# 147      80460.000   0.365   0.375   0.370   0.365
# 148      26764.400   0.250   0.246   0.270   0.243
#
# [149 rows x 13 columns]

# %%
stock_zh_a_spot_df = ak.stock_zh_a_spot()
# Out:
# Please wait for a moment: 100%|████████████████████████████████████████████████████████| 62/62 [00:37<00:00,  1.65it/s]

# %%
stock_zh_a_spot_df
# Out:
#         symbol    code  name  trade  pricechange  changepercent    buy   sell  \
# 0     bj430047  430047  诺思兰德  10.80        -0.04         -0.369  10.80  10.85
# 1     bj430090  430090  同辉信息   3.14         0.06          1.948   3.13   3.14
# 2     bj430198  430198  微创光电   5.09         0.01          0.197   5.07   5.09
# 3     bj430418  430418  苏轴股份   8.53         0.03          0.353   8.51   8.53
# 4     bj430489  430489  佳先股份   6.79         0.14          2.105   6.79   6.83
# ...        ...     ...   ...    ...          ...            ...    ...    ...
# 4882  sz301321  301321  翰博高新  23.33         0.08          0.344  23.33  23.34
# 4883  sz301330  301330  熵基科技  39.48        -0.41         -1.028  39.48  39.49
# 4884  sz301333  301333   诺思格  79.06         0.61          0.778  79.06  79.08
# 4885  sz301336  301336  趣睡科技  62.05         0.35          0.567  62.05  62.10
# 4886  sz301338  301338  凯格精机  56.99         1.19          2.133  56.99  57.00
#
#       settlement   open   high    low     volume       amount  ticktime  \
# 0          10.84  10.93  10.93  10.78   156497.0    1693308.0  15:30:11
# 1           3.08   3.07   3.16   3.07   650810.0    2038330.0  15:30:11
# 2           5.08   5.08   5.09   5.05    46753.0     237476.0  15:30:11
# 3           8.50   8.42   8.55   8.41    65230.0     554153.0  15:30:11
# 4           6.65   6.65   6.95   6.65   637524.0    4349812.0  15:30:11
# ...          ...    ...    ...    ...        ...          ...       ...
# 4882       23.25  23.25  23.43  22.96  2439738.0   56661876.0  15:35:15
# 4883       39.89  39.28  40.16  39.26  2210704.0   87485599.0  15:35:30
# 4884       78.45  78.45  80.00  77.88   534539.0   42200856.0  15:35:45
# 4885       61.70  61.46  63.36  60.61  1507685.0   93596521.0  15:35:00
# 4886       55.80  56.15  57.67  55.60  2161293.0  122718990.0  15:35:15
#
#          per      pb         mktcap            nmc  turnoverratio
# 0    -54.000  12.273  278335.659240  161200.203840        0.10485
# 1     16.649   1.524   62590.733444   37927.635158        0.53880
# 2     14.971   1.332   63180.162504   33038.900379        0.07203
# 3     10.936   1.451   82502.160000   43687.479163        0.12736
# 4      9.301   1.871   92655.796800   56890.306291        0.76090
# ...      ...     ...            ...            ...            ...
# 4882  22.737   2.067  289968.570000  141409.457096        4.02513
# 4883  25.725   4.024  586246.617348  131281.560900        6.64820
# 4884  35.774  10.585  474360.000000  118590.000000        3.56359
# 4885  27.215   5.435  248200.000000   62050.000000       15.07685
# 4886  28.929   8.468  433124.000000   94928.995268       12.97518
#
# [4887 rows x 20 columns]

# %%
stock_zh_a_spot_df
# Out:
#         symbol    code  name  trade  pricechange  changepercent    buy   sell  \
# 0     bj430047  430047  诺思兰德  10.80        -0.04         -0.369  10.80  10.85
# 1     bj430090  430090  同辉信息   3.14         0.06          1.948   3.13   3.14
# 2     bj430198  430198  微创光电   5.09         0.01          0.197   5.07   5.09
# 3     bj430418  430418  苏轴股份   8.53         0.03          0.353   8.51   8.53
# 4     bj430489  430489  佳先股份   6.79         0.14          2.105   6.79   6.83
# ...        ...     ...   ...    ...          ...            ...    ...    ...
# 4882  sz301321  301321  翰博高新  23.33         0.08          0.344  23.33  23.34
# 4883  sz301330  301330  熵基科技  39.48        -0.41         -1.028  39.48  39.49
# 4884  sz301333  301333   诺思格  79.06         0.61          0.778  79.06  79.08
# 4885  sz301336  301336  趣睡科技  62.05         0.35          0.567  62.05  62.10
# 4886  sz301338  301338  凯格精机  56.99         1.19          2.133  56.99  57.00
#
#       settlement   open   high    low     volume       amount  ticktime  \
# 0          10.84  10.93  10.93  10.78   156497.0    1693308.0  15:30:11
# 1           3.08   3.07   3.16   3.07   650810.0    2038330.0  15:30:11
# 2           5.08   5.08   5.09   5.05    46753.0     237476.0  15:30:11
# 3           8.50   8.42   8.55   8.41    65230.0     554153.0  15:30:11
# 4           6.65   6.65   6.95   6.65   637524.0    4349812.0  15:30:11
# ...          ...    ...    ...    ...        ...          ...       ...
# 4882       23.25  23.25  23.43  22.96  2439738.0   56661876.0  15:35:15
# 4883       39.89  39.28  40.16  39.26  2210704.0   87485599.0  15:35:30
# 4884       78.45  78.45  80.00  77.88   534539.0   42200856.0  15:35:45
# 4885       61.70  61.46  63.36  60.61  1507685.0   93596521.0  15:35:00
# 4886       55.80  56.15  57.67  55.60  2161293.0  122718990.0  15:35:15
#
#          per      pb         mktcap            nmc  turnoverratio
# 0    -54.000  12.273  278335.659240  161200.203840        0.10485
# 1     16.649   1.524   62590.733444   37927.635158        0.53880
# 2     14.971   1.332   63180.162504   33038.900379        0.07203
# 3     10.936   1.451   82502.160000   43687.479163        0.12736
# 4      9.301   1.871   92655.796800   56890.306291        0.76090
# ...      ...     ...            ...            ...            ...
# 4882  22.737   2.067  289968.570000  141409.457096        4.02513
# 4883  25.725   4.024  586246.617348  131281.560900        6.64820
# 4884  35.774  10.585  474360.000000  118590.000000        3.56359
# 4885  27.215   5.435  248200.000000   62050.000000       15.07685
# 4886  28.929   8.468  433124.000000   94928.995268       12.97518
#
# [4887 rows x 20 columns]

# %%
stock_zh_a_spot_df.columns
# Out:
# Index(['symbol', 'code', 'name', 'trade', 'pricechange', 'changepercent',
#        'buy', 'sell', 'settlement', 'open', 'high', 'low', 'volume', 'amount',
#        'ticktime', 'per', 'pb', 'mktcap', 'nmc', 'turnoverratio'],
#       dtype='object')

# %%
stock_zh_a_spot_df.shape
# Out:
# (4887, 20)

# %%
stock_zh_a_spot_df.filter(['symbol', 'code', 'name','mktcap']).sort_values(by='mktcap',ascending=False)
# Out:
#         symbol    code  name        mktcap
# 508   sh600519  600519  贵州茅台  2.349090e+08
# 991   sh601398  601398  工商银行  1.553931e+08
# 855   sh600941  600941  中国移动  1.369357e+08
# 1088  sh601939  601939  建设银行  1.367560e+08
# 4430  sz300750  300750  宁德时代  1.199491e+08
# ...        ...     ...   ...           ...
# 75    bj836871  836871   派特尔  4.262034e+04
# 55    bj834765  834765   美之高  4.100208e+04
# 28    bj832145  832145  恒合股份  4.028405e+04
# 67    bj836149  836149  旭杰科技  3.466626e+04
# 62    bj835508  835508  殷图网联  3.430000e+04
#
# [4887 rows x 4 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-5e05d327346f> in <module>
# ----> 1 import QUANTAXIS as QA
#
# ModuleNotFoundError: No module named 'QUANTAXIS'

# %%
import pandas as pd
