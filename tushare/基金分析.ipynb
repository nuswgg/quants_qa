# %%
import tushare as ts
token = "488917d460bca13177c0b510492fc5fc04d0629bc76cc32a4f73fcf0"
ts.set_token(token)
pro = ts.pro_api()

# %% [markdown]
# # 基金列表

# %%
#  E场内
fund_list_E =  pro.fund_basic(market='E')

# %%
# O场外
fund_list_O =  pro.fund_basic(market='O')

# %%
fund_list_E
# Out:
#         ts_code             name management custodian fund_type found_date  \
# 0     180102.SZ       华夏合肥高新REIT       华夏基金    中国工商银行     REITs   20220920
# 1     159645.SZ          疫苗龙头ETF       富国基金      平安银行       股票型   20220916
# 2     562310.SH       沪深300成长ETF       银华基金    中国建设银行       股票型   20220901
# 3     513260.SH        恒生科技ETFQD      汇添富基金      招商银行       股票型   20220831
# 4     159621.SZ       MSCIESGETF       国泰基金      中信银行       股票型   20220830
# ...         ...              ...        ...       ...       ...        ...
# 1694  500017.SH             基金景业       大成基金    中国农业银行       股票型   19920401
# 1695  184702.SZ             基金同智       长盛基金      中国银行       股票型   19920313
# 1696  500028.SH             基金兴业       华夏基金    中国农业银行       股票型   19911115
# 1697  508021.SH  国泰君安临港创新产业园REIT     国泰君安资管      中国银行     REITs       None
# 1698  508088.SH    国泰君安东久新经济REIT     国泰君安资管      中国银行     REITs       None
#
# ...

# %%
fund_list_O
# Out:
#          ts_code           name management   custodian fund_type found_date  \
# 0      012714.OF        长安泓润纯债E       长安基金        交通银行       债券型   20220929
# 1      016728.OF          华安乾煜C       华安基金        招商银行       债券型   20220922
# 2      970186.OF       中原天天汇利货币       中原证券  中国证券登记结算公司     货币市场型   20220922
# 3      016597.OF  民生加银月月乐30天持有C     民生加银基金        中信银行       债券型   20220920
# 4      016596.OF  民生加银月月乐30天持有A     民生加银基金        中信银行       债券型   20220920
# ...          ...            ...        ...         ...       ...        ...
# 14995  673020.OF       西部利得成长精选     西部利得基金        兴业银行       混合型   20150602
# 14996  001245.OF      工银瑞信生态环境A     工银瑞信基金        浦发银行       股票型   20150602
# 14997  001219.OF      上投摩根动态多因子     上投摩根基金      中国建设银行       混合型   20150602
# 14998  001291.OF        大摩量化多策略  摩根士丹利华鑫基金      中国建设银行       股票型   20150602
# 14999  519755.OF       交银多策略回报A    交银施罗德基金      中国农业银行       混合型   20150602
#
# ...

# %%
# 场内基金的类型
fund_list_E.fund_type.unique()
# Out:
# array(['REITs', '股票型', '混合型', '商品型', '债券型', '货币市场型', '另类投资型'],
#       dtype=object)

# %%
# 基金的类型
fund_list_O.fund_type.unique()
# Out:
# array(['债券型', '货币市场型', '混合型', '股票型', '商品型', '保本型', '另类投资型'], dtype=object)

# %%
fund_list_O.columns
# Out:
# Index(['ts_code', 'name', 'management', 'custodian', 'fund_type', 'found_date',
#        'due_date', 'list_date', 'issue_date', 'delist_date', 'issue_amount',
#        'm_fee', 'c_fee', 'duration_year', 'p_value', 'min_amount',
#        'exp_return', 'benchmark', 'status', 'invest_type', 'type', 'trustee',
#        'purc_startdate', 'redm_startdate', 'market'],
#       dtype='object')

# %%
np.nan == np.nan
# Out:
# False

# %%
fund_list.filter(['ts_code','fund_type','found_date','list_date','delist_date','m_fee','c_fee','benchmark','invest_type','purc_startdate'])
# .query("benchmark == benchmark")
# .query("delist_date != delist_date")
# status 存续状态D摘牌 I发行 L已上市
# Out:
#         ts_code fund_type found_date list_date delist_date  m_fee  c_fee  \
# 0     508058.SH     REITs   20220822  20220831        None   0.19   0.01
# 1     180501.SZ     REITs   20220822  20220831        None   0.20   0.01
# 2     508068.SH     REITs   20220822  20220831        None   0.12   0.01
# 3     159637.SZ       股票型   20220819  20220901        None   0.50   0.05
# 4     159631.SZ       股票型   20220818  20220826        None   0.50   0.10
# ...         ...       ...        ...       ...         ...    ...    ...
# 1686  500019.SH       股票型   19920509  20010904    20070425   1.50   0.25
# 1687  500013.SH       股票型   19920429  20010830    20070410   1.50   0.25
# 1688  500017.SH       股票型   19920401  20011219    20070116   1.50   0.25
# 1689  184702.SZ       股票型   19920313  20000515    20070105   1.50   0.25
# 1690  500028.SH       股票型   19911115  20010727    20060809   1.50   0.25
#
#          benchmark invest_type purc_startdate
# ...

# %% [markdown]
# # 查询基金代码

# %%
fund_list_E.query('ts_code.str.contains("508018")',engine='python')
# 159638.SZ
# 159638
# Out:
#       ts_code        name management custodian fund_type found_date due_date  \
# 60  508018.SH  华夏中国交建REIT       华夏基金    中国农业银行     REITs   20220413     None
#
#    list_date issue_date delist_date  ...  min_amount  exp_return  benchmark  \
# 60  20220428   20220407        None  ...         NaN        None       None
#
#     status  invest_type    type trustee purc_startdate redm_startdate market
# 60       L         None  契约型封闭式    None           None           None      E
#
# [1 rows x 25 columns]

# %%
fund_list_E.query("ts_code=='159638.SZ'")
# Out:
#      ts_code     name management custodian fund_type found_date due_date  \
# 8  159638.SZ  高端装备ETF       嘉实基金      兴业银行       股票型   20220805     None
#
#   list_date issue_date delist_date  ...  min_amount  exp_return  \
# 8  20220812   20220718        None  ...         0.1        None
#
#          benchmark  status  invest_type    type trustee purc_startdate  \
# 8  中证高端装备细分50指数收益率       L        被动指数型  契约型开放式    None       20220812
#
#   redm_startdate market
# 8       20220812      E
#
# [1 rows x 25 columns]

# %% [markdown]
# # 基金规模

# %%
# pro.fund_share(ts_code='150018.SZ')
pro.fund_share(ts_code='508018.SH')
# Out:
#       ts_code trade_date  fd_share fund_type market
# 0   508018.SH   20220913  100000.0      None     SH
# 1   508018.SH   20220909  100000.0      None     SH
# 2   508018.SH   20220908  100000.0      None     SH
# 3   508018.SH   20220907  100000.0      None     SH
# 4   508018.SH   20220906  100000.0      None     SH
# ..        ...        ...       ...       ...    ...
# 91  508018.SH   20220429  100000.0      None     SH
# 92  508018.SH   20220428  100000.0      None     SH
# 93  508018.SH   20220427  100000.0      None     SH
# 94  508018.SH   20220421  100000.0      None     SH
# 95  508018.SH   20220413  100000.0      None     SH
#
# [96 rows x 5 columns]

# %% [markdown]
# # 基金持仓

# %%
## 军工ETF
df = pro.fund_portfolio(ts_code='512660.SH') #半导体ETF
df.query('end_date == "20220630"').sort_values(by='stk_mkv_ratio',ascending = 0)
# df
# Out:
#        ts_code  ann_date  end_date     symbol           mkv      amount  \
# 9    512660.SH  20220721  20220630  600893.SH  6.885413e+08  15129450.0
# 2    512660.SH  20220721  20220630  002179.SZ  5.755675e+08   9089822.0
# 0    512660.SH  20220721  20220630  000733.SZ  5.485125e+08   4034070.0
# 7    512660.SH  20220721  20220630  600760.SH  5.486881e+08   9076727.0
# 1    512660.SH  20220721  20220630  000768.SZ  4.888159e+08  16137863.0
# ..         ...       ...       ...        ...           ...         ...
# 69   512660.SH  20220830  20220630  301222.SZ  9.614720e+03       332.0
# 70   512660.SH  20220830  20220630  301238.SZ  1.121488e+05      3497.0
# 71   512660.SH  20220830  20220630  301239.SZ  1.933865e+05      5747.0
# 72   512660.SH  20220830  20220630  301263.SZ  2.140116e+04       682.0
# 102  512660.SH  20220830  20220630  688290.SH  1.424848e+05      3040.0
#
#      stk_mkv_ratio  stk_float_ratio
# 9             5.82             0.65
# ...

# %% [markdown]
# ## 房地产ETF

# %%
df = pro.fund_portfolio(ts_code='159768.SZ') #房地产ETF
df.query('end_date == "20220630"').sort_values(by='stk_mkv_ratio',ascending = 0)
# df
# Out:
#       ts_code  ann_date  end_date     symbol          mkv     amount  \
# 27  159768.SZ  20220719  20220630  000002.SZ  41185709.50  2009059.0
# 12  159768.SZ  20220719  20220630  600048.SH  40927986.00  2344100.0
# 24  159768.SZ  20220719  20220630  001979.SZ  24828041.00  1848700.0
# 3   159768.SZ  20220719  20220630  600383.SH  21370944.00  1590100.0
# 26  159768.SZ  20220719  20220630  000069.SZ  15531868.00  2393200.0
# 7   159768.SZ  20220719  20220630  601155.SH  13505873.00   531100.0
# 4   159768.SZ  20220719  20220630  600606.SH   8888220.00  2244500.0
# 2   159768.SZ  20220719  20220630  600325.SH   7549561.00   997300.0
# 5   159768.SZ  20220719  20220630  600848.SH   7521732.00   554700.0
# 1   159768.SZ  20220719  20220630  600208.SH   6944712.00  2516200.0
# 17  159768.SZ  20220829  20220630  002244.SZ   6271250.00   725000.0
# 11  159768.SZ  20220829  20220630  000656.SZ   6238518.00  2181300.0
# 23  159768.SZ  20220829  20220630  600895.SH   5571375.00   447500.0
# ...

# %%
df = pro.fund_portfolio(ts_code='512200.SH') #房地产ETF
df.query('end_date == "20220630"').sort_values(by='stk_mkv_ratio',ascending = 0)
# df
# Out:
#       ts_code  ann_date  end_date     symbol           mkv      amount  \
# 0   512200.SH  20220721  20220630  000002.SZ  8.097656e+08  39500762.0
# 5   512200.SH  20220721  20220630  600048.SH  7.994708e+08  45788705.0
# 2   512200.SH  20220721  20220630  001979.SZ  4.444766e+08  33095800.0
# 8   512200.SH  20220721  20220630  600383.SH  3.777052e+08  28103063.0
# 1   512200.SH  20220721  20220630  000069.SZ  2.772165e+08  42714400.0
# ..        ...       ...       ...        ...           ...         ...
# 62  512200.SH  20220831  20220630  301207.SZ  3.210298e+04       569.0
# 14  512200.SH  20220721  20220630  688267.SH  1.081410e+05      3390.0
# 63  512200.SH  20220831  20220630  301248.SZ  1.409864e+04       472.0
# 59  512200.SH  20220831  20220630  301153.SZ  1.750404e+04       398.0
# 58  512200.SH  20220831  20220630  301150.SZ  3.343504e+04       404.0
#
#     stk_mkv_ratio  stk_float_ratio
# 0           11.08             0.41
# 5           10.94             0.38
# ...

# %% [markdown]
# ## 半导体ETF

# %%
df = pro.fund_portfolio(ts_code='512480.SH') #半导体ETF
df.query('end_date == "20220630"').sort_values(by='stk_mkv_ratio',ascending = 0)
# df
# Out:
#       ts_code  ann_date  end_date     symbol           mkv      amount  \
# 8   512480.SH  20220721  20220630  603986.SH  7.779055e+08   5470118.0
# 7   512480.SH  20220721  20220630  603501.SH  7.669051e+08   4432209.0
# 14  512480.SH  20220721  20220630  688981.SH  7.417969e+08  16422335.0
# 0   512480.SH  20220721  20220630  002049.SZ  6.850673e+08   3610939.0
# 1   512480.SH  20220721  20220630  002371.SZ  6.305483e+08   2275362.0
# ..        ...       ...       ...        ...           ...         ...
# 53  512480.SH  20220831  20220630  301162.SZ  1.807274e+04       334.0
# 52  512480.SH  20220831  20220630  301158.SZ  7.724020e+03       379.0
# 51  512480.SH  20220831  20220630  301153.SZ  1.750404e+04       398.0
# 79  512480.SH  20220831  20220630  601089.SH  3.681645e+04      1749.0
# 54  512480.SH  20220831  20220630  301175.SZ  2.433111e+05     63694.0
#
#     stk_mkv_ratio  stk_float_ratio
# 8            7.23             0.83
# 7            7.13             0.56
# ...

# %% [markdown]
# ## 芯片ETF

# %%
# df = pro.fund_portfolio(ts_code='159638.SZ')
# df = pro.fund_portfolio(ts_code='508018.SH')
df = pro.fund_portfolio(ts_code='159995.SZ') #芯片ETF
df.query('end_date == "20220630"').sort_values(by='stk_mkv_ratio',ascending = 0)
# Out:
#       ts_code  ann_date  end_date     symbol           mkv      amount  \
# 1   159995.SZ  20220720  20220630  002129.SZ  2.193865e+09  37253608.0
# 7   159995.SZ  20220720  20220630  603501.SH  1.499026e+09   8663387.0
# 0   159995.SZ  20220720  20220630  002049.SZ  1.282780e+09   6761440.0
# 8   159995.SZ  20220720  20220630  603986.SH  1.283708e+09   9026847.0
# 9   159995.SZ  20220720  20220630  688981.SH  1.244025e+09  27540956.0
# ..        ...       ...       ...        ...           ...         ...
# 40  159995.SZ  20220830  20220630  301212.SZ  1.384448e+04       416.0
# 41  159995.SZ  20220830  20220630  301219.SZ  5.075996e+04       578.0
# 42  159995.SZ  20220830  20220630  301220.SZ  1.115775e+04       285.0
# 43  159995.SZ  20220830  20220630  301228.SZ  7.586820e+03       373.0
# 34  159995.SZ  20220830  20220630  301162.SZ  1.807274e+04       334.0
#
#     stk_mkv_ratio  stk_float_ratio
# 1           11.32             1.15
# 7            7.74             1.09
# ...

# %% [markdown]
# ## 证券ETF

# %%
df = pro.fund_portfolio(ts_code='512880.SH') #证券ETF
df.query('end_date == "20160801"').sort_values(by='stk_mkv_ratio',ascending = 0)
# Out:
#         ts_code  ann_date  end_date     symbol         mkv    amount  \
# 1005  512880.SH  20160803  20160801  600030.SH  13586995.0  841300.0
# 1007  512880.SH  20160803  20160801  600837.SH   6940296.0  457200.0
# 1002  512880.SH  20160803  20160801  000776.SZ   6644253.0  410900.0
# 1009  512880.SH  20160803  20160801  601555.SH   5724320.0  430400.0
# 1008  512880.SH  20160803  20160801  601377.SH   4353229.8  571290.0
# 1001  512880.SH  20160803  20160801  000166.SZ   4188016.0  683200.0
# 1010  512880.SH  20160803  20160801  601688.SH   3746250.0  199800.0
# 1003  512880.SH  20160803  20160801  000783.SZ   3548010.0  340500.0
# 1004  512880.SH  20160803  20160801  002736.SZ   3257455.0  201700.0
# 1006  512880.SH  20160803  20160801  600109.SH   3064320.0  239400.0
#
#       stk_mkv_ratio  stk_float_ratio
# 1005          16.11             0.01
# 1007           8.23             0.01
# 1002           7.88             0.01
# 1009           6.79             0.02
# ...

# %%
df.query("end_date=='20220630'").groupby(['ts_code'])['stk_mkv_ratio'].sum()
# Out:
# Series([], Name: stk_mkv_ratio, dtype: float64)

# %%
df.query("end_date=='20220630' and stk_mkv_ratio>1").sort_values(by='stk_mkv_ratio',ascending=0)
# Out:
#        ts_code  ann_date  end_date     symbol          mkv    amount  \
# 8    001753.OF  20220721  20220630  601012.SH  30847024.80  462960.0
# 5    001753.OF  20220721  20220630  002466.SZ  29764800.00  238500.0
# 9    001753.OF  20220721  20220630  605117.SH  27630740.80   98720.0
# 4    001753.OF  20220721  20220630  002459.SZ  22490287.20  285048.0
# 6    001753.OF  20220721  20220630  002594.SZ  19475816.00   58400.0
# 2    001753.OF  20220721  20220630  002176.SZ  18803662.80  750945.0
# 7    001753.OF  20220721  20220630  002756.SZ  16841123.24  110644.0
# 3    001753.OF  20220721  20220630  002192.SZ  15247040.00   99200.0
# 1    001753.OF  20220721  20220630  000625.SZ  13810656.24  797382.0
# 0    001753.OF  20220721  20220630  000408.SZ  13253079.60  402340.0
# 328  001753.OF  20220831  20220630  688156.SH  10775574.72  505184.0
# 230  001753.OF  20220831  20220630  600884.SH   9106208.00  306400.0
# 43   001753.OF  20220831  20220630  002129.SZ   8615607.00  146300.0
# ...

# %% [markdown]
# ## 军工ETF

# %%
df = pro.fund_portfolio(ts_code='512660.SH') #证券ETF
df.query('end_date == "20220630"').sort_values(by='stk_mkv_ratio',ascending = 0)
# df
# Out:
#        ts_code  ann_date  end_date     symbol           mkv      amount  \
# 9    512660.SH  20220721  20220630  600893.SH  6.885413e+08  15129450.0
# 2    512660.SH  20220721  20220630  002179.SZ  5.755675e+08   9089822.0
# 0    512660.SH  20220721  20220630  000733.SZ  5.485125e+08   4034070.0
# 7    512660.SH  20220721  20220630  600760.SH  5.486881e+08   9076727.0
# 1    512660.SH  20220721  20220630  000768.SZ  4.888159e+08  16137863.0
# ..         ...       ...       ...        ...           ...         ...
# 69   512660.SH  20220830  20220630  301222.SZ  9.614720e+03       332.0
# 70   512660.SH  20220830  20220630  301238.SZ  1.121488e+05      3497.0
# 71   512660.SH  20220830  20220630  301239.SZ  1.933865e+05      5747.0
# 72   512660.SH  20220830  20220630  301263.SZ  2.140116e+04       682.0
# 102  512660.SH  20220830  20220630  688290.SH  1.424848e+05      3040.0
#
#      stk_mkv_ratio  stk_float_ratio
# 9             5.82             0.65
# ...

# %% [markdown]
# ## 上证50eft

# %%
df = pro.fund_portfolio(ts_code='510050.SH') #证券ETF
df.query('end_date == "20220630"').sort_values(by='stk_mkv_ratio',ascending = 0)
# df
# Out:
#       ts_code  ann_date  end_date     symbol           mkv       amount  \
# 1   510050.SH  20220720  20220630  600519.SH  8.798081e+09    4302240.0
# 0   510050.SH  20220720  20220630  600036.SH  3.580432e+09   84844361.0
# 6   510050.SH  20220720  20220630  601318.SH  3.467315e+09   74262479.0
# 8   510050.SH  20220720  20220630  601012.SH  2.769368e+09   41563375.0
# 5   510050.SH  20220720  20220630  601166.SH  1.983757e+09   99686275.0
# 4   510050.SH  20220720  20220630  600900.SH  1.802284e+09   77953451.0
# 7   510050.SH  20220720  20220630  601888.SH  1.557102e+09    6684851.0
# 9   510050.SH  20220720  20220630  603259.SH  1.461519e+09   14054415.0
# 3   510050.SH  20220720  20220630  600030.SH  1.449263e+09   66909640.0
# 2   510050.SH  20220720  20220630  600887.SH  1.366932e+09   35094528.0
# 10  510050.SH  20220830  20220630  601398.SH  1.146057e+09  240263553.0
# 11  510050.SH  20220830  20220630  600276.SH  1.135345e+09   30610538.0
# ...

# %% [markdown]
# ## 沪深300etf

# %%
df = pro.fund_portfolio(ts_code='510300.SH') #证券ETF
df.query('end_date == "20220630"').sort_values(by='stk_mkv_ratio',ascending = 0)
# df
# Out:
#        ts_code  ann_date  end_date     symbol           mkv      amount  \
# 49   510300.SH  20220721  20220630  600519.SH  2.908131e+09   1422069.0
# 63   510300.SH  20220721  20220630  300750.SZ  1.699555e+09   3182687.0
# 50   510300.SH  20220721  20220630  600036.SH  1.184124e+09  28059802.0
# 61   510300.SH  20220721  20220630  601318.SH  1.145997e+09  24544806.0
# 56   510300.SH  20220721  20220630  601012.SH  9.153681e+08  13738077.0
# ..         ...       ...       ...        ...           ...         ...
# 191  510300.SH  20220830  20220630  301158.SZ  7.724020e+03       379.0
# 159  510300.SH  20220830  20220630  601089.SH  3.681645e+04      1749.0
# 160  510300.SH  20220830  20220630  301200.SZ  4.449544e+04       857.0
# 188  510300.SH  20220830  20220630  301279.SZ  6.751760e+03       296.0
# 173  510300.SH  20220830  20220630  301259.SZ  1.204602e+04       483.0
#
#      stk_mkv_ratio  stk_float_ratio
# 49            6.11             0.11
# ...

# %%
level_2_index = pro.index_classify(level='L2',src='SW2021')

# %%
level_2_index
# Out:
#     index_code industry_name level industry_code is_pub parent_code
# 0    801016.SI           种植业    L2        110100      1      110000
# 1    801015.SI            渔业    L2        110200      1      110000
# 2    801011.SI           林业Ⅱ    L2        110300      0      110000
# 3    801014.SI            饲料    L2        110400      1      110000
# 4    801012.SI         农产品加工    L2        110500      1      110000
# ..         ...           ...   ...           ...    ...         ...
# 129  801971.SI          环境治理    L2        760100      1      760000
# 130  801972.SI         环保设备Ⅱ    L2        760200      1      760000
# 131  801981.SI          个护用品    L2        770100      1      770000
# 132  801982.SI           化妆品    L2        770200      1      770000
# 133  801983.SI          医疗美容    L2        770300      0      770000
#
# [134 rows x 6 columns]

# %%
index_all
# Out:
#     index_code industry_name level industry_code is_pub parent_code
# 0    801010.SI          农林牧渔    L1        110000      1           0
# 1    801030.SI          基础化工    L1        220000      1           0
# 2    801040.SI            钢铁    L1        230000      1           0
# 3    801050.SI          有色金属    L1        240000      1           0
# 4    801080.SI            电子    L1        270000      1           0
# ..         ...           ...   ...           ...    ...         ...
# 506  859812.SI          洗护用品    L3        770102      0      770100
# 507  859821.SI      化妆品制造及其他    L3        770201      1      770200
# 508  859822.SI         品牌化妆品    L3        770202      1      770200
# 509  859831.SI          医美耗材    L3        770301      0      770300
# 510  859832.SI          医美服务    L3        770302      0      770300
#
# [511 rows x 6 columns]

# %%
dir(ts)
# Out:
# ['MailMerge',
#  'TraderAPI',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'bar',
#  'bdi',
#  'broker_tops',
#  'cap_tops',
#  'close_apis',
#  'codecs',
#  'coins',
#  'coins_bar',
#  'coins_snapshot',
#  'coins_tick',
#  'coins_trade',
#  'day_boxoffice',
#  'day_cinema',
#  'forecast_data',
#  'fund',
#  'fund_holdings',
#  'futures',
#  'get_apis',
#  'get_area_classified',
#  'get_balance_sheet',
#  'get_cash_flow',
#  'get_cashflow_data',
#  'get_cffex_daily',
#  'get_concept_classified',
#  'get_cpi',
#  'get_czce_daily',
#  'get_day_all',
#  'get_dce_daily',
#  'get_debtpaying_data',
#  'get_deposit_rate',
#  'get_fund_info',
#  'get_future_daily',
#  'get_gdp_contrib',
#  'get_gdp_for',
#  'get_gdp_pull',
#  'get_gdp_quarter',
#  'get_gdp_year',
#  'get_gem_classified',
#  'get_gold_and_foreign_reserves',
#  'get_growth_data',
# ...
